# %%
import polars as pl
from great_tables import GT
from great_tables.data import exibble

# %% [markdown]
# ## data_color

# %%
df = pl.from_pandas(exibble)
with pl.Config(tbl_cols=7):
    print(df)
# Out:
# shape: (8, 9)
# ┌──────────┬────────────┬───────┬────────────┬───┬──────────┬───────┬───────┐
# │ num      ┆ char       ┆ fctr  ┆ date       ┆ … ┆ currency ┆ row   ┆ group │
# │ ---      ┆ ---        ┆ ---   ┆ ---        ┆   ┆ ---      ┆ ---   ┆ ---   │
# │ f64      ┆ str        ┆ str   ┆ str        ┆   ┆ f64      ┆ str   ┆ str   │
# ╞══════════╪════════════╪═══════╪════════════╪═══╪══════════╪═══════╪═══════╡
# │ 0.1111   ┆ apricot    ┆ one   ┆ 2015-01-15 ┆ … ┆ 49.95    ┆ row_1 ┆ grp_a │
# │ 2.222    ┆ banana     ┆ two   ┆ 2015-02-15 ┆ … ┆ 17.95    ┆ row_2 ┆ grp_a │
# │ 33.33    ┆ coconut    ┆ three ┆ 2015-03-15 ┆ … ┆ 1.39     ┆ row_3 ┆ grp_a │
# │ 444.4    ┆ durian     ┆ four  ┆ 2015-04-15 ┆ … ┆ 65100.0  ┆ row_4 ┆ grp_a │
# │ 5550.0   ┆ null       ┆ five  ┆ 2015-05-15 ┆ … ┆ 1325.81  ┆ row_5 ┆ grp_b │
# │ null     ┆ fig        ┆ six   ┆ 2015-06-15 ┆ … ┆ 13.255   ┆ row_6 ┆ grp_b │
# │ 777000.0 ┆ grapefruit ┆ seven ┆ null       ┆ … ┆ null     ┆ row_7 ┆ grp_b │
# │ 8.88e6   ┆ honeydew   ┆ eight ┆ 2015-08-15 ┆ … ┆ 0.44     ┆ row_8 ┆ grp_b │
# └──────────┴────────────┴───────┴────────────┴───┴──────────┴───────┴───────┘

# %%
# default
(GT(df).data_color())
# Out:
# GT(_tbl_data=shape: (8, 9)
# ┌──────────┬────────────┬───────┬────────────┬───┬──────────────────┬──────────┬───────┬───────┐
# │ num      ┆ char       ┆ fctr  ┆ date       ┆ … ┆ datetime         ┆ currency ┆ row   ┆ group │
# │ ---      ┆ ---        ┆ ---   ┆ ---        ┆   ┆ ---              ┆ ---      ┆ ---   ┆ ---   │
# │ f64      ┆ str        ┆ str   ┆ str        ┆   ┆ str              ┆ f64      ┆ str   ┆ str   │
# ╞══════════╪════════════╪═══════╪════════════╪═══╪══════════════════╪══════════╪═══════╪═══════╡
# │ 0.1111   ┆ apricot    ┆ one   ┆ 2015-01-15 ┆ … ┆ 2018-01-01 02:22 ┆ 49.95    ┆ row_1 ┆ grp_a │
# │ 2.222    ┆ banana     ┆ two   ┆ 2015-02-15 ┆ … ┆ 2018-02-02 14:33 ┆ 17.95    ┆ row_2 ┆ grp_a │
# │ 33.33    ┆ coconut    ┆ three ┆ 2015-03-15 ┆ … ┆ 2018-03-03 03:44 ┆ 1.39     ┆ row_3 ┆ grp_a │
# │ 444.4    ┆ durian     ┆ four  ┆ 2015-04-15 ┆ … ┆ 2018-04-04 15:55 ┆ 65100.0  ┆ row_4 ┆ grp_a │
# │ 5550.0   ┆ null       ┆ five  ┆ 2015-05-15 ┆ … ┆ 2018-05-05 04:00 ┆ 1325.81  ┆ row_5 ┆ grp_b │
# │ null     ┆ fig        ┆ six   ┆ 2015-06-15 ┆ … ┆ 2018-06-06 16:11 ┆ 13.255   ┆ row_6 ┆ grp_b │
# │ 777000.0 ┆ grapefruit ┆ seven ┆ null       ┆ … ┆ 2018-07-07 05:22 ┆ null     ┆ row_7 ┆ grp_b │
# │ 8.88e6   ┆ honeydew   ┆ eight ┆ 2015-08-15 ┆ … ┆ null             ┆ 0.44     ┆ row_8 ┆ grp_b │
# └──────────┴────────────┴───────┴────────────┴───┴──────────────────┴──────────┴───────┴───────┘, _body=<great_tables._gt_data.Body object at 0x00000210B6CE5E10>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='fctr', type=<ColInfoTypeEnum.default: 1>, column_label='fctr', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='left', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='left', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='left', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.default: 1>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000210B802FC90>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=0, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#000000')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=1, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#000000')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=2, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#000000')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=3, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#000000')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=4, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#010000')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=5, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#808080')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=6, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#893342')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=7, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#9e9e9e')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='char', rownum=0, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_ ...

# %%
# palette
(GT(df).data_color(columns="row", palette="Blues"))
# Out:
# GT(_tbl_data=shape: (8, 9)
# ┌──────────┬────────────┬───────┬────────────┬───┬──────────────────┬──────────┬───────┬───────┐
# │ num      ┆ char       ┆ fctr  ┆ date       ┆ … ┆ datetime         ┆ currency ┆ row   ┆ group │
# │ ---      ┆ ---        ┆ ---   ┆ ---        ┆   ┆ ---              ┆ ---      ┆ ---   ┆ ---   │
# │ f64      ┆ str        ┆ str   ┆ str        ┆   ┆ str              ┆ f64      ┆ str   ┆ str   │
# ╞══════════╪════════════╪═══════╪════════════╪═══╪══════════════════╪══════════╪═══════╪═══════╡
# │ 0.1111   ┆ apricot    ┆ one   ┆ 2015-01-15 ┆ … ┆ 2018-01-01 02:22 ┆ 49.95    ┆ row_1 ┆ grp_a │
# │ 2.222    ┆ banana     ┆ two   ┆ 2015-02-15 ┆ … ┆ 2018-02-02 14:33 ┆ 17.95    ┆ row_2 ┆ grp_a │
# │ 33.33    ┆ coconut    ┆ three ┆ 2015-03-15 ┆ … ┆ 2018-03-03 03:44 ┆ 1.39     ┆ row_3 ┆ grp_a │
# │ 444.4    ┆ durian     ┆ four  ┆ 2015-04-15 ┆ … ┆ 2018-04-04 15:55 ┆ 65100.0  ┆ row_4 ┆ grp_a │
# │ 5550.0   ┆ null       ┆ five  ┆ 2015-05-15 ┆ … ┆ 2018-05-05 04:00 ┆ 1325.81  ┆ row_5 ┆ grp_b │
# │ null     ┆ fig        ┆ six   ┆ 2015-06-15 ┆ … ┆ 2018-06-06 16:11 ┆ 13.255   ┆ row_6 ┆ grp_b │
# │ 777000.0 ┆ grapefruit ┆ seven ┆ null       ┆ … ┆ 2018-07-07 05:22 ┆ null     ┆ row_7 ┆ grp_b │
# │ 8.88e6   ┆ honeydew   ┆ eight ┆ 2015-08-15 ┆ … ┆ null             ┆ 0.44     ┆ row_8 ┆ grp_b │
# └──────────┴────────────┴───────┴────────────┴───┴──────────────────┴──────────┴───────┴───────┘, _body=<great_tables._gt_data.Body object at 0x00000210B5FD52D0>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='fctr', type=<ColInfoTypeEnum.default: 1>, column_label='fctr', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='left', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='left', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='left', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.default: 1>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000210B81D9750>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='row', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#f7fbff')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='row', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#deebf7')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='row', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#c6dbef')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='row', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#9ecae1')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='row', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#6baed6')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='row', rownum=5, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#4292c6')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='row', rownum=6, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#2171b5')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='row', rownum=7, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#08519c')])], _locale=<great_tables._gt_data.Locale object at 0x00000210B81DA990>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='ta ...

# %%
# palette - multiple colors
(
    GT(df).data_color(
        columns="row", palette=["rebeccapurple", "white", "orange"]
    )
)
# Out:
# GT(_tbl_data=shape: (8, 9)
# ┌──────────┬────────────┬───────┬────────────┬───┬──────────────────┬──────────┬───────┬───────┐
# │ num      ┆ char       ┆ fctr  ┆ date       ┆ … ┆ datetime         ┆ currency ┆ row   ┆ group │
# │ ---      ┆ ---        ┆ ---   ┆ ---        ┆   ┆ ---              ┆ ---      ┆ ---   ┆ ---   │
# │ f64      ┆ str        ┆ str   ┆ str        ┆   ┆ str              ┆ f64      ┆ str   ┆ str   │
# ╞══════════╪════════════╪═══════╪════════════╪═══╪══════════════════╪══════════╪═══════╪═══════╡
# │ 0.1111   ┆ apricot    ┆ one   ┆ 2015-01-15 ┆ … ┆ 2018-01-01 02:22 ┆ 49.95    ┆ row_1 ┆ grp_a │
# │ 2.222    ┆ banana     ┆ two   ┆ 2015-02-15 ┆ … ┆ 2018-02-02 14:33 ┆ 17.95    ┆ row_2 ┆ grp_a │
# │ 33.33    ┆ coconut    ┆ three ┆ 2015-03-15 ┆ … ┆ 2018-03-03 03:44 ┆ 1.39     ┆ row_3 ┆ grp_a │
# │ 444.4    ┆ durian     ┆ four  ┆ 2015-04-15 ┆ … ┆ 2018-04-04 15:55 ┆ 65100.0  ┆ row_4 ┆ grp_a │
# │ 5550.0   ┆ null       ┆ five  ┆ 2015-05-15 ┆ … ┆ 2018-05-05 04:00 ┆ 1325.81  ┆ row_5 ┆ grp_b │
# │ null     ┆ fig        ┆ six   ┆ 2015-06-15 ┆ … ┆ 2018-06-06 16:11 ┆ 13.255   ┆ row_6 ┆ grp_b │
# │ 777000.0 ┆ grapefruit ┆ seven ┆ null       ┆ … ┆ 2018-07-07 05:22 ┆ null     ┆ row_7 ┆ grp_b │
# │ 8.88e6   ┆ honeydew   ┆ eight ┆ 2015-08-15 ┆ … ┆ null             ┆ 0.44     ┆ row_8 ┆ grp_b │
# └──────────┴────────────┴───────┴────────────┴───┴──────────────────┴──────────┴───────┴───────┘, _body=<great_tables._gt_data.Body object at 0x00000210B811B190>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='fctr', type=<ColInfoTypeEnum.default: 1>, column_label='fctr', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='left', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='left', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='left', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.default: 1>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000210B811A550>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='row', rownum=0, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#663399')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='row', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#8c66b2')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='row', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#b299cc')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='row', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#d9cce6')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='row', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#ffffff')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='row', rownum=5, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#ffe8bf')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='row', rownum=6, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#ffd280')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='row', rownum=7, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#ffbc40')])], _locale=<great_tables._gt_data.Locale object at 0x00000210B811B0D0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='ta ...

# %%
# domain
(GT(df).data_color(columns="num", palette="Oranges", domain=[0, 5600]))
# Out:
# GT(_tbl_data=shape: (8, 9)
# ┌──────────┬────────────┬───────┬────────────┬───┬──────────────────┬──────────┬───────┬───────┐
# │ num      ┆ char       ┆ fctr  ┆ date       ┆ … ┆ datetime         ┆ currency ┆ row   ┆ group │
# │ ---      ┆ ---        ┆ ---   ┆ ---        ┆   ┆ ---              ┆ ---      ┆ ---   ┆ ---   │
# │ f64      ┆ str        ┆ str   ┆ str        ┆   ┆ str              ┆ f64      ┆ str   ┆ str   │
# ╞══════════╪════════════╪═══════╪════════════╪═══╪══════════════════╪══════════╪═══════╪═══════╡
# │ 0.1111   ┆ apricot    ┆ one   ┆ 2015-01-15 ┆ … ┆ 2018-01-01 02:22 ┆ 49.95    ┆ row_1 ┆ grp_a │
# │ 2.222    ┆ banana     ┆ two   ┆ 2015-02-15 ┆ … ┆ 2018-02-02 14:33 ┆ 17.95    ┆ row_2 ┆ grp_a │
# │ 33.33    ┆ coconut    ┆ three ┆ 2015-03-15 ┆ … ┆ 2018-03-03 03:44 ┆ 1.39     ┆ row_3 ┆ grp_a │
# │ 444.4    ┆ durian     ┆ four  ┆ 2015-04-15 ┆ … ┆ 2018-04-04 15:55 ┆ 65100.0  ┆ row_4 ┆ grp_a │
# │ 5550.0   ┆ null       ┆ five  ┆ 2015-05-15 ┆ … ┆ 2018-05-05 04:00 ┆ 1325.81  ┆ row_5 ┆ grp_b │
# │ null     ┆ fig        ┆ six   ┆ 2015-06-15 ┆ … ┆ 2018-06-06 16:11 ┆ 13.255   ┆ row_6 ┆ grp_b │
# │ 777000.0 ┆ grapefruit ┆ seven ┆ null       ┆ … ┆ 2018-07-07 05:22 ┆ null     ┆ row_7 ┆ grp_b │
# │ 8.88e6   ┆ honeydew   ┆ eight ┆ 2015-08-15 ┆ … ┆ null             ┆ 0.44     ┆ row_8 ┆ grp_b │
# └──────────┴────────────┴───────┴────────────┴───┴──────────────────┴──────────┴───────┴───────┘, _body=<great_tables._gt_data.Body object at 0x00000210B81F5D90>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='fctr', type=<ColInfoTypeEnum.default: 1>, column_label='fctr', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='left', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='left', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='left', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.default: 1>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000210B81F4D50>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#fff5eb')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#fff5eb')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#fff4ea')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#feebd9')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=4, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#822804')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=5, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#808080')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=6, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#808080')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=7, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#808080')])], _locale=<great_tables._gt_data.Locale object at 0x00000210B81F40D0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='ta ...

# %%
# na_color
(
    GT(df).data_color(
        columns="num",
        palette="Oranges",
        domain=[0, 5600],
        na_color="lightgreen",
    )
)
# Out:
# GT(_tbl_data=shape: (8, 9)
# ┌──────────┬────────────┬───────┬────────────┬───┬──────────────────┬──────────┬───────┬───────┐
# │ num      ┆ char       ┆ fctr  ┆ date       ┆ … ┆ datetime         ┆ currency ┆ row   ┆ group │
# │ ---      ┆ ---        ┆ ---   ┆ ---        ┆   ┆ ---              ┆ ---      ┆ ---   ┆ ---   │
# │ f64      ┆ str        ┆ str   ┆ str        ┆   ┆ str              ┆ f64      ┆ str   ┆ str   │
# ╞══════════╪════════════╪═══════╪════════════╪═══╪══════════════════╪══════════╪═══════╪═══════╡
# │ 0.1111   ┆ apricot    ┆ one   ┆ 2015-01-15 ┆ … ┆ 2018-01-01 02:22 ┆ 49.95    ┆ row_1 ┆ grp_a │
# │ 2.222    ┆ banana     ┆ two   ┆ 2015-02-15 ┆ … ┆ 2018-02-02 14:33 ┆ 17.95    ┆ row_2 ┆ grp_a │
# │ 33.33    ┆ coconut    ┆ three ┆ 2015-03-15 ┆ … ┆ 2018-03-03 03:44 ┆ 1.39     ┆ row_3 ┆ grp_a │
# │ 444.4    ┆ durian     ┆ four  ┆ 2015-04-15 ┆ … ┆ 2018-04-04 15:55 ┆ 65100.0  ┆ row_4 ┆ grp_a │
# │ 5550.0   ┆ null       ┆ five  ┆ 2015-05-15 ┆ … ┆ 2018-05-05 04:00 ┆ 1325.81  ┆ row_5 ┆ grp_b │
# │ null     ┆ fig        ┆ six   ┆ 2015-06-15 ┆ … ┆ 2018-06-06 16:11 ┆ 13.255   ┆ row_6 ┆ grp_b │
# │ 777000.0 ┆ grapefruit ┆ seven ┆ null       ┆ … ┆ 2018-07-07 05:22 ┆ null     ┆ row_7 ┆ grp_b │
# │ 8.88e6   ┆ honeydew   ┆ eight ┆ 2015-08-15 ┆ … ┆ null             ┆ 0.44     ┆ row_8 ┆ grp_b │
# └──────────┴────────────┴───────┴────────────┴───┴──────────────────┴──────────┴───────┴───────┘, _body=<great_tables._gt_data.Body object at 0x00000210B81E62D0>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='fctr', type=<ColInfoTypeEnum.default: 1>, column_label='fctr', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='left', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='left', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='left', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.default: 1>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000210B81F4410>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#fff5eb')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#fff5eb')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#fff4ea')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#feebd9')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=4, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#822804')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=5, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#90EE90')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=6, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#90EE90')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=7, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#90EE90')])], _locale=<great_tables._gt_data.Locale object at 0x00000210B810D950>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='ta ...

# %%
# multiple `GT.data_color()`
(
    GT(df)
    .data_color(
        columns="num",
        palette="Oranges",
        domain=[0, 5600],
        na_color="lightgreen",
    )
    .data_color(
        columns="currency",
        palette="Purples",
        domain=[0, 50],
        na_color="lightgreen",
    )
)
# Out:
# GT(_tbl_data=shape: (8, 9)
# ┌──────────┬────────────┬───────┬────────────┬───┬──────────────────┬──────────┬───────┬───────┐
# │ num      ┆ char       ┆ fctr  ┆ date       ┆ … ┆ datetime         ┆ currency ┆ row   ┆ group │
# │ ---      ┆ ---        ┆ ---   ┆ ---        ┆   ┆ ---              ┆ ---      ┆ ---   ┆ ---   │
# │ f64      ┆ str        ┆ str   ┆ str        ┆   ┆ str              ┆ f64      ┆ str   ┆ str   │
# ╞══════════╪════════════╪═══════╪════════════╪═══╪══════════════════╪══════════╪═══════╪═══════╡
# │ 0.1111   ┆ apricot    ┆ one   ┆ 2015-01-15 ┆ … ┆ 2018-01-01 02:22 ┆ 49.95    ┆ row_1 ┆ grp_a │
# │ 2.222    ┆ banana     ┆ two   ┆ 2015-02-15 ┆ … ┆ 2018-02-02 14:33 ┆ 17.95    ┆ row_2 ┆ grp_a │
# │ 33.33    ┆ coconut    ┆ three ┆ 2015-03-15 ┆ … ┆ 2018-03-03 03:44 ┆ 1.39     ┆ row_3 ┆ grp_a │
# │ 444.4    ┆ durian     ┆ four  ┆ 2015-04-15 ┆ … ┆ 2018-04-04 15:55 ┆ 65100.0  ┆ row_4 ┆ grp_a │
# │ 5550.0   ┆ null       ┆ five  ┆ 2015-05-15 ┆ … ┆ 2018-05-05 04:00 ┆ 1325.81  ┆ row_5 ┆ grp_b │
# │ null     ┆ fig        ┆ six   ┆ 2015-06-15 ┆ … ┆ 2018-06-06 16:11 ┆ 13.255   ┆ row_6 ┆ grp_b │
# │ 777000.0 ┆ grapefruit ┆ seven ┆ null       ┆ … ┆ 2018-07-07 05:22 ┆ null     ┆ row_7 ┆ grp_b │
# │ 8.88e6   ┆ honeydew   ┆ eight ┆ 2015-08-15 ┆ … ┆ null             ┆ 0.44     ┆ row_8 ┆ grp_b │
# └──────────┴────────────┴───────┴────────────┴───┴──────────────────┴──────────┴───────┴───────┘, _body=<great_tables._gt_data.Body object at 0x00000210B810C9D0>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='fctr', type=<ColInfoTypeEnum.default: 1>, column_label='fctr', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='left', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='left', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='left', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.default: 1>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000210B8136E90>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#fff5eb')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#fff5eb')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#fff4ea')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#feebd9')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=4, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#822804')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=5, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#90EE90')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=6, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#90EE90')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='num', rownum=7, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#90EE90')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='currency', rownum=0, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None ...

# %%
# rows
(
    GT(df).data_color(
        columns="currency",
        rows=pl.col("currency").lt(50),
        palette="Purples",
        domain=[0, 50],  # not influenced by `rows`
        na_color="lightgreen",
    )
)
# Out:
# GT(_tbl_data=shape: (8, 9)
# ┌──────────┬────────────┬───────┬────────────┬───┬──────────────────┬──────────┬───────┬───────┐
# │ num      ┆ char       ┆ fctr  ┆ date       ┆ … ┆ datetime         ┆ currency ┆ row   ┆ group │
# │ ---      ┆ ---        ┆ ---   ┆ ---        ┆   ┆ ---              ┆ ---      ┆ ---   ┆ ---   │
# │ f64      ┆ str        ┆ str   ┆ str        ┆   ┆ str              ┆ f64      ┆ str   ┆ str   │
# ╞══════════╪════════════╪═══════╪════════════╪═══╪══════════════════╪══════════╪═══════╪═══════╡
# │ 0.1111   ┆ apricot    ┆ one   ┆ 2015-01-15 ┆ … ┆ 2018-01-01 02:22 ┆ 49.95    ┆ row_1 ┆ grp_a │
# │ 2.222    ┆ banana     ┆ two   ┆ 2015-02-15 ┆ … ┆ 2018-02-02 14:33 ┆ 17.95    ┆ row_2 ┆ grp_a │
# │ 33.33    ┆ coconut    ┆ three ┆ 2015-03-15 ┆ … ┆ 2018-03-03 03:44 ┆ 1.39     ┆ row_3 ┆ grp_a │
# │ 444.4    ┆ durian     ┆ four  ┆ 2015-04-15 ┆ … ┆ 2018-04-04 15:55 ┆ 65100.0  ┆ row_4 ┆ grp_a │
# │ 5550.0   ┆ null       ┆ five  ┆ 2015-05-15 ┆ … ┆ 2018-05-05 04:00 ┆ 1325.81  ┆ row_5 ┆ grp_b │
# │ null     ┆ fig        ┆ six   ┆ 2015-06-15 ┆ … ┆ 2018-06-06 16:11 ┆ 13.255   ┆ row_6 ┆ grp_b │
# │ 777000.0 ┆ grapefruit ┆ seven ┆ null       ┆ … ┆ 2018-07-07 05:22 ┆ null     ┆ row_7 ┆ grp_b │
# │ 8.88e6   ┆ honeydew   ┆ eight ┆ 2015-08-15 ┆ … ┆ null             ┆ 0.44     ┆ row_8 ┆ grp_b │
# └──────────┴────────────┴───────┴────────────┴───┴──────────────────┴──────────┴───────┴───────┘, _body=<great_tables._gt_data.Body object at 0x00000210B8111450>, _boxhead=Boxhead([ColInfo(var='num', type=<ColInfoTypeEnum.default: 1>, column_label='num', column_align='right', column_width=None), ColInfo(var='char', type=<ColInfoTypeEnum.default: 1>, column_label='char', column_align='left', column_width=None), ColInfo(var='fctr', type=<ColInfoTypeEnum.default: 1>, column_label='fctr', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='left', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='left', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='left', column_width=None), ColInfo(var='currency', type=<ColInfoTypeEnum.default: 1>, column_label='currency', column_align='right', column_width=None), ColInfo(var='row', type=<ColInfoTypeEnum.default: 1>, column_label='row', column_align='left', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000210B810F2D0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='currency', rownum=0, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#3f007d')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='currency', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#c0c1de')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='currency', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#f9f8fb')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='currency', rownum=5, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#d6d6e9')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='currency', rownum=7, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#fbfafc')])], _locale=<great_tables._gt_data.Locale object at 0x00000210B8111210>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value=' ...
