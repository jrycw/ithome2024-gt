# %% [markdown]
# ## Collect data

# %%
import polars as pl
from great_tables import GT, style, loc, nanoplot_options
import yfinance as yf


input_filename = "tsm.csv"


def _collect_data(filename: str) -> None:
    tsm = yf.download(
        "TSM", start="2019-01-01", end="2023-12-31", interval="1mo"
    )
    tsm.to_csv(filename)


_collect_data(input_filename)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Generate df

# %%
(
    pl.read_csv(input_filename)
    .with_columns(
        pl.col("Date").cast(pl.Date),
        pl.col("Close").alias("lines"),
    )
    .group_by_dynamic("Date", every="1y")
    .agg("lines")
)
# Out:
# shape: (5, 2)
# ┌────────────┬─────────────────────────────────┐
# │ Date       ┆ lines                           │
# │ ---        ┆ ---                             │
# │ date       ┆ list[f64]                       │
# ╞════════════╪═════════════════════════════════╡
# │ 2019-01-01 ┆ [37.619999, 39.049999, … 58.09… │
# │ 2020-01-01 ┆ [53.939999, 53.84, … 109.04000… │
# │ 2021-01-01 ┆ [121.519997, 125.940002, … 120… │
# │ 2022-01-01 ┆ [122.629997, 107.010002, … 74.… │
# │ 2023-01-01 ┆ [92.730003, 87.07, … 104.0]     │
# └────────────┴─────────────────────────────────┘

# %%
month_cols = [f"{month_index:02}" for month_index in range(1, 13)]


def tweak_df(filename: str) -> pl.DataFrame:
    return (
        pl.read_csv(filename)
        .with_columns(
            pl.col("Date").cast(pl.Date),
            pl.col("Close").alias("lines"),
        )
        .group_by_dynamic("Date", every="1y")
        .agg("lines")
        .with_columns(
            pl.col("Date").dt.year().alias("year"),
            *[
                pl.col("lines").list.get(idx).alias(month)
                for idx, month in enumerate(month_cols)
            ],
            pl.col("lines").alias("bars"),
        )
        .select("year", *month_cols, "lines", "bars")
    )


df = tweak_df(input_filename)
df
# Out:
# shape: (5, 15)
# ┌──────┬────────────┬────────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ year ┆ 01         ┆ 02         ┆ 03         ┆ … ┆ 11         ┆ 12        ┆ lines     ┆ bars      │
# │ ---  ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │ i32  ┆ f64        ┆ f64        ┆ f64        ┆   ┆ f64        ┆ f64       ┆ list[f64] ┆ list[f64] │
# ╞══════╪════════════╪════════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2019 ┆ 37.619999  ┆ 39.049999  ┆ 40.959999  ┆ … ┆ 53.09      ┆ 58.099998 ┆ [37.61999 ┆ [37.61999 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 9, 39.049 ┆ 9, 39.049 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 999, …    ┆ 999, …    │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 58.09…    ┆ 58.09…    │
# │ 2020 ┆ 53.939999  ┆ 53.84      ┆ 47.790001  ┆ … ┆ 97.019997  ┆ 109.04000 ┆ [53.93999 ┆ [53.93999 │
# │      ┆            ┆            ┆            ┆   ┆            ┆ 1         ┆ 9, 53.84, ┆ 9, 53.84, │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ … 109.040 ┆ … 109.040 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 00…       ┆ 00…       │
# │ 2021 ┆ 121.519997 ┆ 125.940002 ┆ 118.279999 ┆ … ┆ 117.150002 ┆ 120.30999 ┆ [121.5199 ┆ [121.5199 │
# │      ┆            ┆            ┆            ┆   ┆            ┆ 8         ┆ 97, 125.9 ┆ 97, 125.9 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 40002, …  ┆ 40002, …  │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 120…      ┆ 120…      │
# │ 2022 ┆ 122.629997 ┆ 107.010002 ┆ 104.260002 ┆ … ┆ 82.980003  ┆ 74.489998 ┆ [122.6299 ┆ [122.6299 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 97, 107.0 ┆ 97, 107.0 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 10002, …  ┆ 10002, …  │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 74.…      ┆ 74.…      │
# │ 2023 ┆ 92.730003  ┆ 87.07      ┆ 93.019997  ┆ … ┆ 97.309998  ┆ 104.0     ┆ [92.73000 ┆ [92.73000 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 3, 87.07, ┆ 3, 87.07, │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ … 104.0]  ┆ … 104.0]  │
# └──────┴────────────┴────────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Make table

# %%
def make_gt(df: pl.DataFrame) -> GT:
    domain_min = df.select(month_cols).min().min_horizontal().item()  # 37.61
    domain_max = df.select(month_cols).max().max_horizontal().item()  # 125.94
    return (
        GT(df)
        .tab_header("TSM Stock Price", "2019 ~ 2023")
        .tab_spanner(label="Month", columns=month_cols)
        .tab_spanner(label="Trend", columns=["lines", "bars"])
        .tab_options(table_background_color="#F1F1F1")
        .data_color(
            columns=month_cols,
            palette=["#F5EFE7", "#E7CE91"],
            domain=[domain_min * 0.99, domain_max * 1.01],
        )
        .tab_style(
            style=[style.text(color="red"), style.text(weight="Bold")],
            locations=[
                loc.body(columns="02", rows=2),
                loc.body(columns="01", rows=0),
            ],
        )
        .fmt_currency(month_cols)
        .opt_all_caps()
        .fmt_nanoplot(
            "lines",
            plot_type="line",
            reference_line="mean",
            options=nanoplot_options(
                reference_line_color="black",
                show_reference_line=True,
                currency="USD",
            ),
        )
        .fmt_nanoplot(
            "bars",
            plot_type="bar",
            autoscale=True,
            options=nanoplot_options(currency="USD"),
        )
    )


gtbl = make_gt(df)
gtbl
# Out:
# GT(_tbl_data=shape: (5, 15)
# ┌──────┬────────────┬────────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ year ┆ 01         ┆ 02         ┆ 03         ┆ … ┆ 11         ┆ 12        ┆ lines     ┆ bars      │
# │ ---  ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │ i32  ┆ f64        ┆ f64        ┆ f64        ┆   ┆ f64        ┆ f64       ┆ list[f64] ┆ list[f64] │
# ╞══════╪════════════╪════════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2019 ┆ 37.619999  ┆ 39.049999  ┆ 40.959999  ┆ … ┆ 53.09      ┆ 58.099998 ┆ [37.61999 ┆ [37.61999 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 9, 39.049 ┆ 9, 39.049 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 999, …    ┆ 999, …    │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 58.09…    ┆ 58.09…    │
# │ 2020 ┆ 53.939999  ┆ 53.84      ┆ 47.790001  ┆ … ┆ 97.019997  ┆ 109.04000 ┆ [53.93999 ┆ [53.93999 │
# │      ┆            ┆            ┆            ┆   ┆            ┆ 1         ┆ 9, 53.84, ┆ 9, 53.84, │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ … 109.040 ┆ … 109.040 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 00…       ┆ 00…       │
# │ 2021 ┆ 121.519997 ┆ 125.940002 ┆ 118.279999 ┆ … ┆ 117.150002 ┆ 120.30999 ┆ [121.5199 ┆ [121.5199 │
# │      ┆            ┆            ┆            ┆   ┆            ┆ 8         ┆ 97, 125.9 ┆ 97, 125.9 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 40002, …  ┆ 40002, …  │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 120…      ┆ 120…      │
# │ 2022 ┆ 122.629997 ┆ 107.010002 ┆ 104.260002 ┆ … ┆ 82.980003  ┆ 74.489998 ┆ [122.6299 ┆ [122.6299 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 97, 107.0 ┆ 97, 107.0 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 10002, …  ┆ 10002, …  │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 74.…      ┆ 74.…      │
# │ 2023 ┆ 92.730003  ┆ 87.07      ┆ 93.019997  ┆ … ┆ 97.309998  ┆ 104.0     ┆ [92.73000 ┆ [92.73000 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ 3, 87.07, ┆ 3, 87.07, │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆ … 104.0]  ┆ … 104.0]  │
# └──────┴────────────┴────────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘, _body=<great_tables._gt_data.Body object at 0x000001D59446F950>, _boxhead=Boxhead([ColInfo(var='year', type=<ColInfoTypeEnum.default: 1>, column_label='year', column_align='right', column_width=None), ColInfo(var='01', type=<ColInfoTypeEnum.default: 1>, column_label='01', column_align='right', column_width=None), ColInfo(var='02', type=<ColInfoTypeEnum.default: 1>, column_label='02', column_align='right', column_width=None), ColInfo(var='03', type=<ColInfoTypeEnum.default: 1>, column_label='03', column_align='right', column_width=None), ColInfo(var='04', type=<ColInfoTypeEnum.default: 1>, column_label='04', column_align='right', column_width=None), ColInfo(var='05', type=<ColInfoTypeEnum.default: 1>, column_label='05', column_align='right', column_width=None), ColInfo(var='06', type=<ColInfoTypeEnum.default: 1>, column_label='06', column_align='right', column_width=None), ColInfo(var='07', type=<ColInfoTypeEnum.default: 1>, column_label='07', column_align='right', column_width=None), ColInfo(var='08', type=<ColInfoTypeEnum.default: 1>, column_label='08', column_align='right', column_width=None), ColInfo(var='09', type=<ColInfoTypeEnum.default: 1>, column_label='09', column_align='right', column_width=None), ColInfo(var='10', type=<ColInfoTypeEnum.default: 1>, column_label='10', column_align='right', column_width=None), ColInfo(var='11', type=<ColInfoTypeEnum.default: 1>, column_label='11', column_align='right', column_width=None), ColInfo(var='12', type=<ColInfoTypeEnum.default: 1>, column_label='12', column_align='right', column_width=None), ColInfo(var='lines', type=<ColInfoTypeEnum.default: 1>, column_label='lines', column_align='center', column_width=None), ColInfo(var='bars', type=<ColInfoTypeEnum.default: 1>, column_label='bars', column_align='center', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001D591D8EE90>, _spanners=Spanners([SpannerInfo(spanner_id='Month', spanner_level=0, spanner_label='Month', spanner_units=None, spanner_pattern=None, vars=['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12'], built=None), SpannerInfo(spanner_id='Trend', spanner_level=0, spanner_label='Trend', spanner_units=None, spanner_pattern=None, vars=['lines', 'bars'], built=None)]), _heading=Heading(title='TSM Stock Price', subtitle='2019 ~ 2023', preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='01', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#f5efe7')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='01', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#f2e9d7')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='01', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#e8d096')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='01', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#e8d095')]), StyleInfo(locname='data', locnum=5, grpname=None, colname='01', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#ecdbb2')]), StyleInfo(locname='dat ...

# %% [markdown]
# ## Output HTML

# %%
output_filename = "tsm.html"


def _write_html(gtbl: GT, filename: str) -> None:
    with open(filename, "w") as f:
        f.write(gtbl.as_raw_html())


_write_html(gtbl, output_filename)
