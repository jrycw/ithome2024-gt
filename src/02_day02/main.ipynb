# %% [markdown]
# ## Generate df

# %%
import polars as pl
from great_tables import GT, html, md, style, loc
from great_tables.data import gtcars


df = pl.from_pandas(gtcars.sample(5, random_state=42)).select(
    "mfr", "model", "year", "hp", "trq", "msrp"
)

df
# Out:
# shape: (5, 6)
# ┌──────────────┬──────────┬────────┬───────┬───────┬──────────┐
# │ mfr          ┆ model    ┆ year   ┆ hp    ┆ trq   ┆ msrp     │
# │ ---          ┆ ---      ┆ ---    ┆ ---   ┆ ---   ┆ ---      │
# │ str          ┆ str      ┆ f64    ┆ f64   ┆ f64   ┆ f64      │
# ╞══════════════╪══════════╪════════╪═══════╪═══════╪══════════╡
# │ Aston Martin ┆ Vantage  ┆ 2016.0 ┆ 430.0 ┆ 361.0 ┆ 103300.0 │
# │ Tesla        ┆ Model S  ┆ 2017.0 ┆ 259.0 ┆ 243.0 ┆ 74500.0  │
# │ Aston Martin ┆ Vanquish ┆ 2016.0 ┆ 568.0 ┆ 465.0 ┆ 287250.0 │
# │ Porsche      ┆ Panamera ┆ 2016.0 ┆ 310.0 ┆ 295.0 ┆ 78100.0  │
# │ Aston Martin ┆ DB11     ┆ 2017.0 ┆ 608.0 ┆ 516.0 ┆ 211195.0 │
# └──────────────┴──────────┴────────┴───────┴───────┴──────────┘

# %%
print(df)
# Out:
# shape: (5, 6)
# ┌──────────────┬──────────┬────────┬───────┬───────┬──────────┐
# │ mfr          ┆ model    ┆ year   ┆ hp    ┆ trq   ┆ msrp     │
# │ ---          ┆ ---      ┆ ---    ┆ ---   ┆ ---   ┆ ---      │
# │ str          ┆ str      ┆ f64    ┆ f64   ┆ f64   ┆ f64      │
# ╞══════════════╪══════════╪════════╪═══════╪═══════╪══════════╡
# │ Aston Martin ┆ Vantage  ┆ 2016.0 ┆ 430.0 ┆ 361.0 ┆ 103300.0 │
# │ Tesla        ┆ Model S  ┆ 2017.0 ┆ 259.0 ┆ 243.0 ┆ 74500.0  │
# │ Aston Martin ┆ Vanquish ┆ 2016.0 ┆ 568.0 ┆ 465.0 ┆ 287250.0 │
# │ Porsche      ┆ Panamera ┆ 2016.0 ┆ 310.0 ┆ 295.0 ┆ 78100.0  │
# │ Aston Martin ┆ DB11     ┆ 2017.0 ┆ 608.0 ┆ 516.0 ┆ 211195.0 │
# └──────────────┴──────────┴────────┴───────┴───────┴──────────┘

# %% [markdown]
# ## Default table

# %%
GT(df)
# Out:
# GT(_tbl_data=shape: (5, 6)
# ┌──────────────┬──────────┬────────┬───────┬───────┬──────────┐
# │ mfr          ┆ model    ┆ year   ┆ hp    ┆ trq   ┆ msrp     │
# │ ---          ┆ ---      ┆ ---    ┆ ---   ┆ ---   ┆ ---      │
# │ str          ┆ str      ┆ f64    ┆ f64   ┆ f64   ┆ f64      │
# ╞══════════════╪══════════╪════════╪═══════╪═══════╪══════════╡
# │ Aston Martin ┆ Vantage  ┆ 2016.0 ┆ 430.0 ┆ 361.0 ┆ 103300.0 │
# │ Tesla        ┆ Model S  ┆ 2017.0 ┆ 259.0 ┆ 243.0 ┆ 74500.0  │
# │ Aston Martin ┆ Vanquish ┆ 2016.0 ┆ 568.0 ┆ 465.0 ┆ 287250.0 │
# │ Porsche      ┆ Panamera ┆ 2016.0 ┆ 310.0 ┆ 295.0 ┆ 78100.0  │
# │ Aston Martin ┆ DB11     ┆ 2017.0 ┆ 608.0 ┆ 516.0 ┆ 211195.0 │
# └──────────────┴──────────┴────────┴───────┴───────┴──────────┘, _body=<great_tables._gt_data.Body object at 0x0000029C71024310>, _boxhead=Boxhead([ColInfo(var='mfr', type=<ColInfoTypeEnum.default: 1>, column_label='mfr', column_align='left', column_width=None), ColInfo(var='model', type=<ColInfoTypeEnum.default: 1>, column_label='model', column_align='left', column_width=None), ColInfo(var='year', type=<ColInfoTypeEnum.default: 1>, column_label='year', column_align='right', column_width=None), ColInfo(var='hp', type=<ColInfoTypeEnum.default: 1>, column_label='hp', column_align='right', column_width=None), ColInfo(var='trq', type=<ColInfoTypeEnum.default: 1>, column_label='trq', column_align='right', column_width=None), ColInfo(var='msrp', type=<ColInfoTypeEnum.default: 1>, column_label='msrp', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000029C02D1C690>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000029C02236E50>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=Opt ...

# %% [markdown]
# ## Premade theme

# %%
(GT(df).opt_stylize(style=3, color="gray"))
# Out:
# GT(_tbl_data=shape: (5, 6)
# ┌──────────────┬──────────┬────────┬───────┬───────┬──────────┐
# │ mfr          ┆ model    ┆ year   ┆ hp    ┆ trq   ┆ msrp     │
# │ ---          ┆ ---      ┆ ---    ┆ ---   ┆ ---   ┆ ---      │
# │ str          ┆ str      ┆ f64    ┆ f64   ┆ f64   ┆ f64      │
# ╞══════════════╪══════════╪════════╪═══════╪═══════╪══════════╡
# │ Aston Martin ┆ Vantage  ┆ 2016.0 ┆ 430.0 ┆ 361.0 ┆ 103300.0 │
# │ Tesla        ┆ Model S  ┆ 2017.0 ┆ 259.0 ┆ 243.0 ┆ 74500.0  │
# │ Aston Martin ┆ Vanquish ┆ 2016.0 ┆ 568.0 ┆ 465.0 ┆ 287250.0 │
# │ Porsche      ┆ Panamera ┆ 2016.0 ┆ 310.0 ┆ 295.0 ┆ 78100.0  │
# │ Aston Martin ┆ DB11     ┆ 2017.0 ┆ 608.0 ┆ 516.0 ┆ 211195.0 │
# └──────────────┴──────────┴────────┴───────┴───────┴──────────┘, _body=<great_tables._gt_data.Body object at 0x0000029C02D68990>, _boxhead=Boxhead([ColInfo(var='mfr', type=<ColInfoTypeEnum.default: 1>, column_label='mfr', column_align='left', column_width=None), ColInfo(var='model', type=<ColInfoTypeEnum.default: 1>, column_label='model', column_align='left', column_width=None), ColInfo(var='year', type=<ColInfoTypeEnum.default: 1>, column_label='year', column_align='right', column_width=None), ColInfo(var='hp', type=<ColInfoTypeEnum.default: 1>, column_label='hp', column_align='right', column_width=None), ColInfo(var='trq', type=<ColInfoTypeEnum.default: 1>, column_label='trq', column_align='right', column_width=None), ColInfo(var='msrp', type=<ColInfoTypeEnum.default: 1>, column_label='msrp', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000029C02D89590>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000029C02D89990>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#929292'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#929292'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=Opt ...

# %% [markdown]
# ## Table header

# %%
(
    GT(df)
    .opt_stylize(style=3, color="gray")
    .tab_header("Deluxe automobiles", "2014 - 2017")
)
# Out:
# GT(_tbl_data=shape: (5, 6)
# ┌──────────────┬──────────┬────────┬───────┬───────┬──────────┐
# │ mfr          ┆ model    ┆ year   ┆ hp    ┆ trq   ┆ msrp     │
# │ ---          ┆ ---      ┆ ---    ┆ ---   ┆ ---   ┆ ---      │
# │ str          ┆ str      ┆ f64    ┆ f64   ┆ f64   ┆ f64      │
# ╞══════════════╪══════════╪════════╪═══════╪═══════╪══════════╡
# │ Aston Martin ┆ Vantage  ┆ 2016.0 ┆ 430.0 ┆ 361.0 ┆ 103300.0 │
# │ Tesla        ┆ Model S  ┆ 2017.0 ┆ 259.0 ┆ 243.0 ┆ 74500.0  │
# │ Aston Martin ┆ Vanquish ┆ 2016.0 ┆ 568.0 ┆ 465.0 ┆ 287250.0 │
# │ Porsche      ┆ Panamera ┆ 2016.0 ┆ 310.0 ┆ 295.0 ┆ 78100.0  │
# │ Aston Martin ┆ DB11     ┆ 2017.0 ┆ 608.0 ┆ 516.0 ┆ 211195.0 │
# └──────────────┴──────────┴────────┴───────┴───────┴──────────┘, _body=<great_tables._gt_data.Body object at 0x0000029C02D8BE90>, _boxhead=Boxhead([ColInfo(var='mfr', type=<ColInfoTypeEnum.default: 1>, column_label='mfr', column_align='left', column_width=None), ColInfo(var='model', type=<ColInfoTypeEnum.default: 1>, column_label='model', column_align='left', column_width=None), ColInfo(var='year', type=<ColInfoTypeEnum.default: 1>, column_label='year', column_align='right', column_width=None), ColInfo(var='hp', type=<ColInfoTypeEnum.default: 1>, column_label='hp', column_align='right', column_width=None), ColInfo(var='trq', type=<ColInfoTypeEnum.default: 1>, column_label='trq', column_align='right', column_width=None), ColInfo(var='msrp', type=<ColInfoTypeEnum.default: 1>, column_label='msrp', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000029C02D8BB90>, _spanners=Spanners([]), _heading=Heading(title='Deluxe automobiles', subtitle='2014 - 2017', preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000029C02D8BF50>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#929292'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#929292'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), he ...

# %% [markdown]
# ## Table Stub and Table Stubhead

# %%
(
    GT(df)
    .opt_stylize(style=3, color="gray")
    .tab_header("Deluxe automobiles", "2014 - 2017")
    .tab_stub(groupname_col="mfr", rowname_col="model")
    .tab_stubhead(label="Car")
)
# Out:
# GT(_tbl_data=shape: (5, 6)
# ┌──────────────┬──────────┬────────┬───────┬───────┬──────────┐
# │ mfr          ┆ model    ┆ year   ┆ hp    ┆ trq   ┆ msrp     │
# │ ---          ┆ ---      ┆ ---    ┆ ---   ┆ ---   ┆ ---      │
# │ str          ┆ str      ┆ f64    ┆ f64   ┆ f64   ┆ f64      │
# ╞══════════════╪══════════╪════════╪═══════╪═══════╪══════════╡
# │ Aston Martin ┆ Vantage  ┆ 2016.0 ┆ 430.0 ┆ 361.0 ┆ 103300.0 │
# │ Tesla        ┆ Model S  ┆ 2017.0 ┆ 259.0 ┆ 243.0 ┆ 74500.0  │
# │ Aston Martin ┆ Vanquish ┆ 2016.0 ┆ 568.0 ┆ 465.0 ┆ 287250.0 │
# │ Porsche      ┆ Panamera ┆ 2016.0 ┆ 310.0 ┆ 295.0 ┆ 78100.0  │
# │ Aston Martin ┆ DB11     ┆ 2017.0 ┆ 608.0 ┆ 516.0 ┆ 211195.0 │
# └──────────────┴──────────┴────────┴───────┴───────┴──────────┘, _body=<great_tables._gt_data.Body object at 0x0000029C02D88250>, _boxhead=Boxhead([ColInfo(var='mfr', type=<ColInfoTypeEnum.row_group: 3>, column_label='mfr', column_align='left', column_width=None), ColInfo(var='model', type=<ColInfoTypeEnum.stub: 2>, column_label='model', column_align='left', column_width=None), ColInfo(var='year', type=<ColInfoTypeEnum.default: 1>, column_label='year', column_align='right', column_width=None), ColInfo(var='hp', type=<ColInfoTypeEnum.default: 1>, column_label='hp', column_align='right', column_width=None), ColInfo(var='trq', type=<ColInfoTypeEnum.default: 1>, column_label='trq', column_align='right', column_width=None), ColInfo(var='msrp', type=<ColInfoTypeEnum.default: 1>, column_label='msrp', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000029C02D8FC10>, _spanners=Spanners([]), _heading=Heading(title='Deluxe automobiles', subtitle='2014 - 2017', preheader=None), _stubhead='Car', _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000029C02D8ED10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#929292'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#929292'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), he ...

# %% [markdown]
# ## Table spanner

# %%
(
    GT(df)
    .opt_stylize(style=3, color="gray")
    .tab_header("Deluxe automobiles", "2014 - 2017")
    .tab_stub(groupname_col="mfr", rowname_col="model")
    .tab_stubhead(label="Car")
    .tab_spanner(label=html("<i>Performance</i>"), columns=["hp", "trq"])
)
# Out:
# GT(_tbl_data=shape: (5, 6)
# ┌──────────────┬──────────┬────────┬───────┬───────┬──────────┐
# │ mfr          ┆ model    ┆ year   ┆ hp    ┆ trq   ┆ msrp     │
# │ ---          ┆ ---      ┆ ---    ┆ ---   ┆ ---   ┆ ---      │
# │ str          ┆ str      ┆ f64    ┆ f64   ┆ f64   ┆ f64      │
# ╞══════════════╪══════════╪════════╪═══════╪═══════╪══════════╡
# │ Aston Martin ┆ Vantage  ┆ 2016.0 ┆ 430.0 ┆ 361.0 ┆ 103300.0 │
# │ Tesla        ┆ Model S  ┆ 2017.0 ┆ 259.0 ┆ 243.0 ┆ 74500.0  │
# │ Aston Martin ┆ Vanquish ┆ 2016.0 ┆ 568.0 ┆ 465.0 ┆ 287250.0 │
# │ Porsche      ┆ Panamera ┆ 2016.0 ┆ 310.0 ┆ 295.0 ┆ 78100.0  │
# │ Aston Martin ┆ DB11     ┆ 2017.0 ┆ 608.0 ┆ 516.0 ┆ 211195.0 │
# └──────────────┴──────────┴────────┴───────┴───────┴──────────┘, _body=<great_tables._gt_data.Body object at 0x0000029C02D85A90>, _boxhead=Boxhead([ColInfo(var='mfr', type=<ColInfoTypeEnum.row_group: 3>, column_label='mfr', column_align='left', column_width=None), ColInfo(var='model', type=<ColInfoTypeEnum.stub: 2>, column_label='model', column_align='left', column_width=None), ColInfo(var='year', type=<ColInfoTypeEnum.default: 1>, column_label='year', column_align='right', column_width=None), ColInfo(var='hp', type=<ColInfoTypeEnum.default: 1>, column_label='hp', column_align='right', column_width=None), ColInfo(var='trq', type=<ColInfoTypeEnum.default: 1>, column_label='trq', column_align='right', column_width=None), ColInfo(var='msrp', type=<ColInfoTypeEnum.default: 1>, column_label='msrp', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000029C02D86990>, _spanners=Spanners([SpannerInfo(spanner_id='<i>Performance</i>', spanner_level=0, spanner_label=Html(text='<i>Performance</i>'), spanner_units=None, spanner_pattern=None, vars=['hp', 'trq'], built=None)]), _heading=Heading(title='Deluxe automobiles', subtitle='2014 - 2017', preheader=None), _stubhead='Car', _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000029C02D85990>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#929292'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#929292'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), hea ...

# %% [markdown]
# ## Columns

# %%
(
    GT(df)
    .opt_stylize(style=3, color="gray")
    .tab_header("Deluxe automobiles", "2014 - 2017")
    .tab_stub(groupname_col="mfr", rowname_col="model")
    .tab_stubhead(label="Car")
    .tab_spanner(label=html("<i>Performance</i>"), columns=["hp", "trq"])
    .cols_label(year="Year")
    .cols_align("center")
)
# Out:
# GT(_tbl_data=shape: (5, 6)
# ┌──────────────┬──────────┬────────┬───────┬───────┬──────────┐
# │ mfr          ┆ model    ┆ year   ┆ hp    ┆ trq   ┆ msrp     │
# │ ---          ┆ ---      ┆ ---    ┆ ---   ┆ ---   ┆ ---      │
# │ str          ┆ str      ┆ f64    ┆ f64   ┆ f64   ┆ f64      │
# ╞══════════════╪══════════╪════════╪═══════╪═══════╪══════════╡
# │ Aston Martin ┆ Vantage  ┆ 2016.0 ┆ 430.0 ┆ 361.0 ┆ 103300.0 │
# │ Tesla        ┆ Model S  ┆ 2017.0 ┆ 259.0 ┆ 243.0 ┆ 74500.0  │
# │ Aston Martin ┆ Vanquish ┆ 2016.0 ┆ 568.0 ┆ 465.0 ┆ 287250.0 │
# │ Porsche      ┆ Panamera ┆ 2016.0 ┆ 310.0 ┆ 295.0 ┆ 78100.0  │
# │ Aston Martin ┆ DB11     ┆ 2017.0 ┆ 608.0 ┆ 516.0 ┆ 211195.0 │
# └──────────────┴──────────┴────────┴───────┴───────┴──────────┘, _body=<great_tables._gt_data.Body object at 0x0000029C02D85250>, _boxhead=Boxhead([ColInfo(var='mfr', type=<ColInfoTypeEnum.row_group: 3>, column_label='mfr', column_align='center', column_width=None), ColInfo(var='model', type=<ColInfoTypeEnum.stub: 2>, column_label='model', column_align='center', column_width=None), ColInfo(var='year', type=<ColInfoTypeEnum.default: 1>, column_label='Year', column_align='center', column_width=None), ColInfo(var='hp', type=<ColInfoTypeEnum.default: 1>, column_label='hp', column_align='center', column_width=None), ColInfo(var='trq', type=<ColInfoTypeEnum.default: 1>, column_label='trq', column_align='center', column_width=None), ColInfo(var='msrp', type=<ColInfoTypeEnum.default: 1>, column_label='msrp', column_align='center', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000029C02DAA310>, _spanners=Spanners([SpannerInfo(spanner_id='<i>Performance</i>', spanner_level=0, spanner_label=Html(text='<i>Performance</i>'), spanner_units=None, spanner_pattern=None, vars=['hp', 'trq'], built=None)]), _heading=Heading(title='Deluxe automobiles', subtitle='2014 - 2017', preheader=None), _stubhead='Car', _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000029C02DA9450>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#929292'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#929292'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D ...

# %% [markdown]
# ## Table body

# %%
(
    GT(df)
    .opt_stylize(style=3, color="gray")
    .tab_header("Deluxe automobiles", "2014 - 2017")
    .tab_stub(groupname_col="mfr", rowname_col="model")
    .tab_stubhead(label="Car")
    .tab_spanner(label=html("<i>Performance</i>"), columns=["hp", "trq"])
    .cols_label(year="Year")
    .cols_align("center")
    .fmt_integer("year", use_seps=False)
    .fmt_integer(["hp", "trq"])
    .fmt_currency("msrp", decimals=0)
    .tab_style(
        style=style.text(color="red"), locations=loc.body(columns="hp")
    )
)
# Out:
# GT(_tbl_data=shape: (5, 6)
# ┌──────────────┬──────────┬────────┬───────┬───────┬──────────┐
# │ mfr          ┆ model    ┆ year   ┆ hp    ┆ trq   ┆ msrp     │
# │ ---          ┆ ---      ┆ ---    ┆ ---   ┆ ---   ┆ ---      │
# │ str          ┆ str      ┆ f64    ┆ f64   ┆ f64   ┆ f64      │
# ╞══════════════╪══════════╪════════╪═══════╪═══════╪══════════╡
# │ Aston Martin ┆ Vantage  ┆ 2016.0 ┆ 430.0 ┆ 361.0 ┆ 103300.0 │
# │ Tesla        ┆ Model S  ┆ 2017.0 ┆ 259.0 ┆ 243.0 ┆ 74500.0  │
# │ Aston Martin ┆ Vanquish ┆ 2016.0 ┆ 568.0 ┆ 465.0 ┆ 287250.0 │
# │ Porsche      ┆ Panamera ┆ 2016.0 ┆ 310.0 ┆ 295.0 ┆ 78100.0  │
# │ Aston Martin ┆ DB11     ┆ 2017.0 ┆ 608.0 ┆ 516.0 ┆ 211195.0 │
# └──────────────┴──────────┴────────┴───────┴───────┴──────────┘, _body=<great_tables._gt_data.Body object at 0x0000029C02D8FD90>, _boxhead=Boxhead([ColInfo(var='mfr', type=<ColInfoTypeEnum.row_group: 3>, column_label='mfr', column_align='center', column_width=None), ColInfo(var='model', type=<ColInfoTypeEnum.stub: 2>, column_label='model', column_align='center', column_width=None), ColInfo(var='year', type=<ColInfoTypeEnum.default: 1>, column_label='Year', column_align='center', column_width=None), ColInfo(var='hp', type=<ColInfoTypeEnum.default: 1>, column_label='hp', column_align='center', column_width=None), ColInfo(var='trq', type=<ColInfoTypeEnum.default: 1>, column_label='trq', column_align='center', column_width=None), ColInfo(var='msrp', type=<ColInfoTypeEnum.default: 1>, column_label='msrp', column_align='center', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000029C02DB6910>, _spanners=Spanners([SpannerInfo(spanner_id='<i>Performance</i>', spanner_level=0, spanner_label=Html(text='<i>Performance</i>'), spanner_units=None, spanner_pattern=None, vars=['hp', 'trq'], built=None)]), _heading=Heading(title='Deluxe automobiles', subtitle='2014 - 2017', preheader=None), _stubhead='Car', _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='hp', rownum=0, colnum=None, styles=[CellStyleText(color='red', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname='data', locnum=5, grpname=None, colname='hp', rownum=1, colnum=None, styles=[CellStyleText(color='red', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname='data', locnum=5, grpname=None, colname='hp', rownum=2, colnum=None, styles=[CellStyleText(color='red', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname='data', locnum=5, grpname=None, colname='hp', rownum=3, colnum=None, styles=[CellStyleText(color='red', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname='data', locnum=5, grpname=None, colname='hp', rownum=4, colnum=None, styles=[CellStyleText(color='red', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)])], _locale=<great_tables._gt_data.Locale object at 0x0000029C02DB5A90>, _formats=[<great_tables._gt_data.FormatInfo object at 0x0000029C02DB42D0>, <great_tables._gt_data.FormatInfo object at 0x0000029C02D8F650>, <great_tables._gt_data.FormatInfo object at 0x0000029C02DB5E90>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color= ...

# %% [markdown]
# ## Table footnote

# %%
(
    GT(df)
    .opt_stylize(style=3, color="gray")
    .tab_header("Deluxe automobiles", "2014 - 2017")
    .tab_stub(groupname_col="mfr", rowname_col="model")
    .tab_stubhead(label="Car")
    .tab_spanner(label=html("<i>Performance</i>"), columns=["hp", "trq"])
    .cols_label(year="Year")
    .cols_align("center")
    .fmt_integer("year", use_seps=False)
    .fmt_integer(["hp", "trq"])
    .fmt_currency("msrp", decimals=0)
    .tab_style(
        style=style.text(color="red"), locations=loc.body(columns="hp")
    )
    .tab_source_note(
        md(
            "[Dataset: gtcars](https://posit-dev.github.io/great-tables/reference/data.gtcars.html#great_tables.data.gtcars)"
        )
    )
)
# Out:
# GT(_tbl_data=shape: (5, 6)
# ┌──────────────┬──────────┬────────┬───────┬───────┬──────────┐
# │ mfr          ┆ model    ┆ year   ┆ hp    ┆ trq   ┆ msrp     │
# │ ---          ┆ ---      ┆ ---    ┆ ---   ┆ ---   ┆ ---      │
# │ str          ┆ str      ┆ f64    ┆ f64   ┆ f64   ┆ f64      │
# ╞══════════════╪══════════╪════════╪═══════╪═══════╪══════════╡
# │ Aston Martin ┆ Vantage  ┆ 2016.0 ┆ 430.0 ┆ 361.0 ┆ 103300.0 │
# │ Tesla        ┆ Model S  ┆ 2017.0 ┆ 259.0 ┆ 243.0 ┆ 74500.0  │
# │ Aston Martin ┆ Vanquish ┆ 2016.0 ┆ 568.0 ┆ 465.0 ┆ 287250.0 │
# │ Porsche      ┆ Panamera ┆ 2016.0 ┆ 310.0 ┆ 295.0 ┆ 78100.0  │
# │ Aston Martin ┆ DB11     ┆ 2017.0 ┆ 608.0 ┆ 516.0 ┆ 211195.0 │
# └──────────────┴──────────┴────────┴───────┴───────┴──────────┘, _body=<great_tables._gt_data.Body object at 0x0000029C02236D50>, _boxhead=Boxhead([ColInfo(var='mfr', type=<ColInfoTypeEnum.row_group: 3>, column_label='mfr', column_align='center', column_width=None), ColInfo(var='model', type=<ColInfoTypeEnum.stub: 2>, column_label='model', column_align='center', column_width=None), ColInfo(var='year', type=<ColInfoTypeEnum.default: 1>, column_label='Year', column_align='center', column_width=None), ColInfo(var='hp', type=<ColInfoTypeEnum.default: 1>, column_label='hp', column_align='center', column_width=None), ColInfo(var='trq', type=<ColInfoTypeEnum.default: 1>, column_label='trq', column_align='center', column_width=None), ColInfo(var='msrp', type=<ColInfoTypeEnum.default: 1>, column_label='msrp', column_align='center', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000029C02DA5A50>, _spanners=Spanners([SpannerInfo(spanner_id='<i>Performance</i>', spanner_level=0, spanner_label=Html(text='<i>Performance</i>'), spanner_units=None, spanner_pattern=None, vars=['hp', 'trq'], built=None)]), _heading=Heading(title='Deluxe automobiles', subtitle='2014 - 2017', preheader=None), _stubhead='Car', _source_notes=[Md(text='[Dataset: gtcars](https://posit-dev.github.io/great-tables/reference/data.gtcars.html#great_tables.data.gtcars)')], _footnotes=[], _styles=[StyleInfo(locname='data', locnum=5, grpname=None, colname='hp', rownum=0, colnum=None, styles=[CellStyleText(color='red', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname='data', locnum=5, grpname=None, colname='hp', rownum=1, colnum=None, styles=[CellStyleText(color='red', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname='data', locnum=5, grpname=None, colname='hp', rownum=2, colnum=None, styles=[CellStyleText(color='red', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname='data', locnum=5, grpname=None, colname='hp', rownum=3, colnum=None, styles=[CellStyleText(color='red', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname='data', locnum=5, grpname=None, colname='hp', rownum=4, colnum=None, styles=[CellStyleText(color='red', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)])], _locale=<great_tables._gt_data.Locale object at 0x0000029C02DAB9D0>, _formats=[<great_tables._gt_data.FormatInfo object at 0x0000029C02DA72D0>, <great_tables._gt_data.FormatInfo object at 0x0000029C02D8F750>, <great_tables._gt_data.FormatInfo object at 0x0000029C02DA7310>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', v ...
