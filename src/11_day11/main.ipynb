# %%
import polars as pl
import polars.selectors as cs
from great_tables import GT
from datetime import date, time, timedelta

# %%
df_demo = pl.DataFrame(
    {
        "int": [1, 2, 3],
        "float1": [4.4, 5.5, 6.6],
        "float2": [7.7, 8.88, 9.999],
        "perc": [0.5401, -0.0895, 0.7946],
        "sci": [10001.001, -20002.002, 30003.003],
        "group": ["A", "B", "B"],
        "str": ["Python", "Ruby", "Rust"],
        "date": pl.date_range(date(2024, 9, 1), date(2024, 9, 3), eager=True),
        "time": pl.time_range(
            start=time(21, 0),
            interval=timedelta(hours=1, minutes=10),
            eager=True,
        ),
    }
).with_columns(
    pl.col("date").dt.combine(pl.col("time")).alias("datetime"),
)
df_demo
# Out:
# shape: (3, 10)
# ┌─────┬────────┬────────┬─────────┬───┬────────┬────────────┬──────────┬─────────────────────┐
# │ int ┆ float1 ┆ float2 ┆ perc    ┆ … ┆ str    ┆ date       ┆ time     ┆ datetime            │
# │ --- ┆ ---    ┆ ---    ┆ ---     ┆   ┆ ---    ┆ ---        ┆ ---      ┆ ---                 │
# │ i64 ┆ f64    ┆ f64    ┆ f64     ┆   ┆ str    ┆ date       ┆ time     ┆ datetime[μs]        │
# ╞═════╪════════╪════════╪═════════╪═══╪════════╪════════════╪══════════╪═════════════════════╡
# │ 1   ┆ 4.4    ┆ 7.7    ┆ 0.5401  ┆ … ┆ Python ┆ 2024-09-01 ┆ 21:00:00 ┆ 2024-09-01 21:00:00 │
# │ 2   ┆ 5.5    ┆ 8.88   ┆ -0.0895 ┆ … ┆ Ruby   ┆ 2024-09-02 ┆ 22:10:00 ┆ 2024-09-02 22:10:00 │
# │ 3   ┆ 6.6    ┆ 9.999  ┆ 0.7946  ┆ … ┆ Rust   ┆ 2024-09-03 ┆ 23:20:00 ┆ 2024-09-03 23:20:00 │
# └─────┴────────┴────────┴─────────┴───┴────────┴────────────┴──────────┴─────────────────────┘

# %% [markdown]
# ## fmt_number

# %%
(GT(df_demo).fmt_number(cs.numeric()))
# Out:
# GT(_tbl_data=shape: (3, 10)
# ┌─────┬────────┬────────┬─────────┬───┬────────┬────────────┬──────────┬─────────────────────┐
# │ int ┆ float1 ┆ float2 ┆ perc    ┆ … ┆ str    ┆ date       ┆ time     ┆ datetime            │
# │ --- ┆ ---    ┆ ---    ┆ ---     ┆   ┆ ---    ┆ ---        ┆ ---      ┆ ---                 │
# │ i64 ┆ f64    ┆ f64    ┆ f64     ┆   ┆ str    ┆ date       ┆ time     ┆ datetime[μs]        │
# ╞═════╪════════╪════════╪═════════╪═══╪════════╪════════════╪══════════╪═════════════════════╡
# │ 1   ┆ 4.4    ┆ 7.7    ┆ 0.5401  ┆ … ┆ Python ┆ 2024-09-01 ┆ 21:00:00 ┆ 2024-09-01 21:00:00 │
# │ 2   ┆ 5.5    ┆ 8.88   ┆ -0.0895 ┆ … ┆ Ruby   ┆ 2024-09-02 ┆ 22:10:00 ┆ 2024-09-02 22:10:00 │
# │ 3   ┆ 6.6    ┆ 9.999  ┆ 0.7946  ┆ … ┆ Rust   ┆ 2024-09-03 ┆ 23:20:00 ┆ 2024-09-03 23:20:00 │
# └─────┴────────┴────────┴─────────┴───┴────────┴────────────┴──────────┴─────────────────────┘, _body=<great_tables._gt_data.Body object at 0x000001D576F0A410>, _boxhead=Boxhead([ColInfo(var='int', type=<ColInfoTypeEnum.default: 1>, column_label='int', column_align='right', column_width=None), ColInfo(var='float1', type=<ColInfoTypeEnum.default: 1>, column_label='float1', column_align='right', column_width=None), ColInfo(var='float2', type=<ColInfoTypeEnum.default: 1>, column_label='float2', column_align='right', column_width=None), ColInfo(var='perc', type=<ColInfoTypeEnum.default: 1>, column_label='perc', column_align='right', column_width=None), ColInfo(var='sci', type=<ColInfoTypeEnum.default: 1>, column_label='sci', column_align='right', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None), ColInfo(var='str', type=<ColInfoTypeEnum.default: 1>, column_label='str', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='center', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001D50686E950>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001D506261810>, _formats=[<great_tables._gt_data.FormatInfo object at 0x000001D5779F7110>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table ...

# %%
(GT(df_demo).fmt_number(cs.numeric(), compact=True))
# Out:
# GT(_tbl_data=shape: (3, 10)
# ┌─────┬────────┬────────┬─────────┬───┬────────┬────────────┬──────────┬─────────────────────┐
# │ int ┆ float1 ┆ float2 ┆ perc    ┆ … ┆ str    ┆ date       ┆ time     ┆ datetime            │
# │ --- ┆ ---    ┆ ---    ┆ ---     ┆   ┆ ---    ┆ ---        ┆ ---      ┆ ---                 │
# │ i64 ┆ f64    ┆ f64    ┆ f64     ┆   ┆ str    ┆ date       ┆ time     ┆ datetime[μs]        │
# ╞═════╪════════╪════════╪═════════╪═══╪════════╪════════════╪══════════╪═════════════════════╡
# │ 1   ┆ 4.4    ┆ 7.7    ┆ 0.5401  ┆ … ┆ Python ┆ 2024-09-01 ┆ 21:00:00 ┆ 2024-09-01 21:00:00 │
# │ 2   ┆ 5.5    ┆ 8.88   ┆ -0.0895 ┆ … ┆ Ruby   ┆ 2024-09-02 ┆ 22:10:00 ┆ 2024-09-02 22:10:00 │
# │ 3   ┆ 6.6    ┆ 9.999  ┆ 0.7946  ┆ … ┆ Rust   ┆ 2024-09-03 ┆ 23:20:00 ┆ 2024-09-03 23:20:00 │
# └─────┴────────┴────────┴─────────┴───┴────────┴────────────┴──────────┴─────────────────────┘, _body=<great_tables._gt_data.Body object at 0x000001D50688BA90>, _boxhead=Boxhead([ColInfo(var='int', type=<ColInfoTypeEnum.default: 1>, column_label='int', column_align='right', column_width=None), ColInfo(var='float1', type=<ColInfoTypeEnum.default: 1>, column_label='float1', column_align='right', column_width=None), ColInfo(var='float2', type=<ColInfoTypeEnum.default: 1>, column_label='float2', column_align='right', column_width=None), ColInfo(var='perc', type=<ColInfoTypeEnum.default: 1>, column_label='perc', column_align='right', column_width=None), ColInfo(var='sci', type=<ColInfoTypeEnum.default: 1>, column_label='sci', column_align='right', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None), ColInfo(var='str', type=<ColInfoTypeEnum.default: 1>, column_label='str', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='center', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001D50689C290>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001D506876CD0>, _formats=[<great_tables._gt_data.FormatInfo object at 0x000001D506106490>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table ...

# %%
(GT(df_demo).fmt_number(cs.numeric(), pattern="__{x}__"))
# Out:
# GT(_tbl_data=shape: (3, 10)
# ┌─────┬────────┬────────┬─────────┬───┬────────┬────────────┬──────────┬─────────────────────┐
# │ int ┆ float1 ┆ float2 ┆ perc    ┆ … ┆ str    ┆ date       ┆ time     ┆ datetime            │
# │ --- ┆ ---    ┆ ---    ┆ ---     ┆   ┆ ---    ┆ ---        ┆ ---      ┆ ---                 │
# │ i64 ┆ f64    ┆ f64    ┆ f64     ┆   ┆ str    ┆ date       ┆ time     ┆ datetime[μs]        │
# ╞═════╪════════╪════════╪═════════╪═══╪════════╪════════════╪══════════╪═════════════════════╡
# │ 1   ┆ 4.4    ┆ 7.7    ┆ 0.5401  ┆ … ┆ Python ┆ 2024-09-01 ┆ 21:00:00 ┆ 2024-09-01 21:00:00 │
# │ 2   ┆ 5.5    ┆ 8.88   ┆ -0.0895 ┆ … ┆ Ruby   ┆ 2024-09-02 ┆ 22:10:00 ┆ 2024-09-02 22:10:00 │
# │ 3   ┆ 6.6    ┆ 9.999  ┆ 0.7946  ┆ … ┆ Rust   ┆ 2024-09-03 ┆ 23:20:00 ┆ 2024-09-03 23:20:00 │
# └─────┴────────┴────────┴─────────┴───┴────────┴────────────┴──────────┴─────────────────────┘, _body=<great_tables._gt_data.Body object at 0x000001D577BB3710>, _boxhead=Boxhead([ColInfo(var='int', type=<ColInfoTypeEnum.default: 1>, column_label='int', column_align='right', column_width=None), ColInfo(var='float1', type=<ColInfoTypeEnum.default: 1>, column_label='float1', column_align='right', column_width=None), ColInfo(var='float2', type=<ColInfoTypeEnum.default: 1>, column_label='float2', column_align='right', column_width=None), ColInfo(var='perc', type=<ColInfoTypeEnum.default: 1>, column_label='perc', column_align='right', column_width=None), ColInfo(var='sci', type=<ColInfoTypeEnum.default: 1>, column_label='sci', column_align='right', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None), ColInfo(var='str', type=<ColInfoTypeEnum.default: 1>, column_label='str', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='center', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001D50689D610>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001D50689D810>, _formats=[<great_tables._gt_data.FormatInfo object at 0x000001D50689F4D0>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table ...

# %% [markdown]
# ## fmt_integer

# %%
(GT(df_demo).fmt_integer("sci"))
# Out:
# GT(_tbl_data=shape: (3, 10)
# ┌─────┬────────┬────────┬─────────┬───┬────────┬────────────┬──────────┬─────────────────────┐
# │ int ┆ float1 ┆ float2 ┆ perc    ┆ … ┆ str    ┆ date       ┆ time     ┆ datetime            │
# │ --- ┆ ---    ┆ ---    ┆ ---     ┆   ┆ ---    ┆ ---        ┆ ---      ┆ ---                 │
# │ i64 ┆ f64    ┆ f64    ┆ f64     ┆   ┆ str    ┆ date       ┆ time     ┆ datetime[μs]        │
# ╞═════╪════════╪════════╪═════════╪═══╪════════╪════════════╪══════════╪═════════════════════╡
# │ 1   ┆ 4.4    ┆ 7.7    ┆ 0.5401  ┆ … ┆ Python ┆ 2024-09-01 ┆ 21:00:00 ┆ 2024-09-01 21:00:00 │
# │ 2   ┆ 5.5    ┆ 8.88   ┆ -0.0895 ┆ … ┆ Ruby   ┆ 2024-09-02 ┆ 22:10:00 ┆ 2024-09-02 22:10:00 │
# │ 3   ┆ 6.6    ┆ 9.999  ┆ 0.7946  ┆ … ┆ Rust   ┆ 2024-09-03 ┆ 23:20:00 ┆ 2024-09-03 23:20:00 │
# └─────┴────────┴────────┴─────────┴───┴────────┴────────────┴──────────┴─────────────────────┘, _body=<great_tables._gt_data.Body object at 0x000001D50689E990>, _boxhead=Boxhead([ColInfo(var='int', type=<ColInfoTypeEnum.default: 1>, column_label='int', column_align='right', column_width=None), ColInfo(var='float1', type=<ColInfoTypeEnum.default: 1>, column_label='float1', column_align='right', column_width=None), ColInfo(var='float2', type=<ColInfoTypeEnum.default: 1>, column_label='float2', column_align='right', column_width=None), ColInfo(var='perc', type=<ColInfoTypeEnum.default: 1>, column_label='perc', column_align='right', column_width=None), ColInfo(var='sci', type=<ColInfoTypeEnum.default: 1>, column_label='sci', column_align='right', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None), ColInfo(var='str', type=<ColInfoTypeEnum.default: 1>, column_label='str', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='center', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001D5068A0E90>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001D5068A1890>, _formats=[<great_tables._gt_data.FormatInfo object at 0x000001D5068A31D0>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table ...

# %%
(GT(df_demo).fmt_integer("sci", scale_by=100))
# Out:
# GT(_tbl_data=shape: (3, 10)
# ┌─────┬────────┬────────┬─────────┬───┬────────┬────────────┬──────────┬─────────────────────┐
# │ int ┆ float1 ┆ float2 ┆ perc    ┆ … ┆ str    ┆ date       ┆ time     ┆ datetime            │
# │ --- ┆ ---    ┆ ---    ┆ ---     ┆   ┆ ---    ┆ ---        ┆ ---      ┆ ---                 │
# │ i64 ┆ f64    ┆ f64    ┆ f64     ┆   ┆ str    ┆ date       ┆ time     ┆ datetime[μs]        │
# ╞═════╪════════╪════════╪═════════╪═══╪════════╪════════════╪══════════╪═════════════════════╡
# │ 1   ┆ 4.4    ┆ 7.7    ┆ 0.5401  ┆ … ┆ Python ┆ 2024-09-01 ┆ 21:00:00 ┆ 2024-09-01 21:00:00 │
# │ 2   ┆ 5.5    ┆ 8.88   ┆ -0.0895 ┆ … ┆ Ruby   ┆ 2024-09-02 ┆ 22:10:00 ┆ 2024-09-02 22:10:00 │
# │ 3   ┆ 6.6    ┆ 9.999  ┆ 0.7946  ┆ … ┆ Rust   ┆ 2024-09-03 ┆ 23:20:00 ┆ 2024-09-03 23:20:00 │
# └─────┴────────┴────────┴─────────┴───┴────────┴────────────┴──────────┴─────────────────────┘, _body=<great_tables._gt_data.Body object at 0x000001D50688BD10>, _boxhead=Boxhead([ColInfo(var='int', type=<ColInfoTypeEnum.default: 1>, column_label='int', column_align='right', column_width=None), ColInfo(var='float1', type=<ColInfoTypeEnum.default: 1>, column_label='float1', column_align='right', column_width=None), ColInfo(var='float2', type=<ColInfoTypeEnum.default: 1>, column_label='float2', column_align='right', column_width=None), ColInfo(var='perc', type=<ColInfoTypeEnum.default: 1>, column_label='perc', column_align='right', column_width=None), ColInfo(var='sci', type=<ColInfoTypeEnum.default: 1>, column_label='sci', column_align='right', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None), ColInfo(var='str', type=<ColInfoTypeEnum.default: 1>, column_label='str', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='center', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001D5068A2050>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001D5068A2750>, _formats=[<great_tables._gt_data.FormatInfo object at 0x000001D5068A2C50>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table ...

# %%
(GT(df_demo).fmt_integer("sci", scale_by=100, use_seps=False))
# Out:
# GT(_tbl_data=shape: (3, 10)
# ┌─────┬────────┬────────┬─────────┬───┬────────┬────────────┬──────────┬─────────────────────┐
# │ int ┆ float1 ┆ float2 ┆ perc    ┆ … ┆ str    ┆ date       ┆ time     ┆ datetime            │
# │ --- ┆ ---    ┆ ---    ┆ ---     ┆   ┆ ---    ┆ ---        ┆ ---      ┆ ---                 │
# │ i64 ┆ f64    ┆ f64    ┆ f64     ┆   ┆ str    ┆ date       ┆ time     ┆ datetime[μs]        │
# ╞═════╪════════╪════════╪═════════╪═══╪════════╪════════════╪══════════╪═════════════════════╡
# │ 1   ┆ 4.4    ┆ 7.7    ┆ 0.5401  ┆ … ┆ Python ┆ 2024-09-01 ┆ 21:00:00 ┆ 2024-09-01 21:00:00 │
# │ 2   ┆ 5.5    ┆ 8.88   ┆ -0.0895 ┆ … ┆ Ruby   ┆ 2024-09-02 ┆ 22:10:00 ┆ 2024-09-02 22:10:00 │
# │ 3   ┆ 6.6    ┆ 9.999  ┆ 0.7946  ┆ … ┆ Rust   ┆ 2024-09-03 ┆ 23:20:00 ┆ 2024-09-03 23:20:00 │
# └─────┴────────┴────────┴─────────┴───┴────────┴────────────┴──────────┴─────────────────────┘, _body=<great_tables._gt_data.Body object at 0x000001D5068A8150>, _boxhead=Boxhead([ColInfo(var='int', type=<ColInfoTypeEnum.default: 1>, column_label='int', column_align='right', column_width=None), ColInfo(var='float1', type=<ColInfoTypeEnum.default: 1>, column_label='float1', column_align='right', column_width=None), ColInfo(var='float2', type=<ColInfoTypeEnum.default: 1>, column_label='float2', column_align='right', column_width=None), ColInfo(var='perc', type=<ColInfoTypeEnum.default: 1>, column_label='perc', column_align='right', column_width=None), ColInfo(var='sci', type=<ColInfoTypeEnum.default: 1>, column_label='sci', column_align='right', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None), ColInfo(var='str', type=<ColInfoTypeEnum.default: 1>, column_label='str', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='center', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001D5068A9B10>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001D5068A86D0>, _formats=[<great_tables._gt_data.FormatInfo object at 0x000001D5068A2910>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table ...

# %% [markdown]
# ## fmt_scientific

# %%
(GT(df_demo).fmt_scientific("sci"))
# Out:
# GT(_tbl_data=shape: (3, 10)
# ┌─────┬────────┬────────┬─────────┬───┬────────┬────────────┬──────────┬─────────────────────┐
# │ int ┆ float1 ┆ float2 ┆ perc    ┆ … ┆ str    ┆ date       ┆ time     ┆ datetime            │
# │ --- ┆ ---    ┆ ---    ┆ ---     ┆   ┆ ---    ┆ ---        ┆ ---      ┆ ---                 │
# │ i64 ┆ f64    ┆ f64    ┆ f64     ┆   ┆ str    ┆ date       ┆ time     ┆ datetime[μs]        │
# ╞═════╪════════╪════════╪═════════╪═══╪════════╪════════════╪══════════╪═════════════════════╡
# │ 1   ┆ 4.4    ┆ 7.7    ┆ 0.5401  ┆ … ┆ Python ┆ 2024-09-01 ┆ 21:00:00 ┆ 2024-09-01 21:00:00 │
# │ 2   ┆ 5.5    ┆ 8.88   ┆ -0.0895 ┆ … ┆ Ruby   ┆ 2024-09-02 ┆ 22:10:00 ┆ 2024-09-02 22:10:00 │
# │ 3   ┆ 6.6    ┆ 9.999  ┆ 0.7946  ┆ … ┆ Rust   ┆ 2024-09-03 ┆ 23:20:00 ┆ 2024-09-03 23:20:00 │
# └─────┴────────┴────────┴─────────┴───┴────────┴────────────┴──────────┴─────────────────────┘, _body=<great_tables._gt_data.Body object at 0x000001D5068A8850>, _boxhead=Boxhead([ColInfo(var='int', type=<ColInfoTypeEnum.default: 1>, column_label='int', column_align='right', column_width=None), ColInfo(var='float1', type=<ColInfoTypeEnum.default: 1>, column_label='float1', column_align='right', column_width=None), ColInfo(var='float2', type=<ColInfoTypeEnum.default: 1>, column_label='float2', column_align='right', column_width=None), ColInfo(var='perc', type=<ColInfoTypeEnum.default: 1>, column_label='perc', column_align='right', column_width=None), ColInfo(var='sci', type=<ColInfoTypeEnum.default: 1>, column_label='sci', column_align='right', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None), ColInfo(var='str', type=<ColInfoTypeEnum.default: 1>, column_label='str', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='center', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001D5068AA290>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001D5068AB050>, _formats=[<great_tables._gt_data.FormatInfo object at 0x000001D5068AB210>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table ...

# %%
(GT(df_demo).fmt_scientific("sci", n_sigfig=10))
# Out:
# GT(_tbl_data=shape: (3, 10)
# ┌─────┬────────┬────────┬─────────┬───┬────────┬────────────┬──────────┬─────────────────────┐
# │ int ┆ float1 ┆ float2 ┆ perc    ┆ … ┆ str    ┆ date       ┆ time     ┆ datetime            │
# │ --- ┆ ---    ┆ ---    ┆ ---     ┆   ┆ ---    ┆ ---        ┆ ---      ┆ ---                 │
# │ i64 ┆ f64    ┆ f64    ┆ f64     ┆   ┆ str    ┆ date       ┆ time     ┆ datetime[μs]        │
# ╞═════╪════════╪════════╪═════════╪═══╪════════╪════════════╪══════════╪═════════════════════╡
# │ 1   ┆ 4.4    ┆ 7.7    ┆ 0.5401  ┆ … ┆ Python ┆ 2024-09-01 ┆ 21:00:00 ┆ 2024-09-01 21:00:00 │
# │ 2   ┆ 5.5    ┆ 8.88   ┆ -0.0895 ┆ … ┆ Ruby   ┆ 2024-09-02 ┆ 22:10:00 ┆ 2024-09-02 22:10:00 │
# │ 3   ┆ 6.6    ┆ 9.999  ┆ 0.7946  ┆ … ┆ Rust   ┆ 2024-09-03 ┆ 23:20:00 ┆ 2024-09-03 23:20:00 │
# └─────┴────────┴────────┴─────────┴───┴────────┴────────────┴──────────┴─────────────────────┘, _body=<great_tables._gt_data.Body object at 0x000001D5068A82D0>, _boxhead=Boxhead([ColInfo(var='int', type=<ColInfoTypeEnum.default: 1>, column_label='int', column_align='right', column_width=None), ColInfo(var='float1', type=<ColInfoTypeEnum.default: 1>, column_label='float1', column_align='right', column_width=None), ColInfo(var='float2', type=<ColInfoTypeEnum.default: 1>, column_label='float2', column_align='right', column_width=None), ColInfo(var='perc', type=<ColInfoTypeEnum.default: 1>, column_label='perc', column_align='right', column_width=None), ColInfo(var='sci', type=<ColInfoTypeEnum.default: 1>, column_label='sci', column_align='right', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None), ColInfo(var='str', type=<ColInfoTypeEnum.default: 1>, column_label='str', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='center', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001D5068B8110>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001D50689E750>, _formats=[<great_tables._gt_data.FormatInfo object at 0x000001D5068BB090>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table ...

# %%
(GT(df_demo).fmt_scientific("sci", force_sign_m=True))
# Out:
# GT(_tbl_data=shape: (3, 10)
# ┌─────┬────────┬────────┬─────────┬───┬────────┬────────────┬──────────┬─────────────────────┐
# │ int ┆ float1 ┆ float2 ┆ perc    ┆ … ┆ str    ┆ date       ┆ time     ┆ datetime            │
# │ --- ┆ ---    ┆ ---    ┆ ---     ┆   ┆ ---    ┆ ---        ┆ ---      ┆ ---                 │
# │ i64 ┆ f64    ┆ f64    ┆ f64     ┆   ┆ str    ┆ date       ┆ time     ┆ datetime[μs]        │
# ╞═════╪════════╪════════╪═════════╪═══╪════════╪════════════╪══════════╪═════════════════════╡
# │ 1   ┆ 4.4    ┆ 7.7    ┆ 0.5401  ┆ … ┆ Python ┆ 2024-09-01 ┆ 21:00:00 ┆ 2024-09-01 21:00:00 │
# │ 2   ┆ 5.5    ┆ 8.88   ┆ -0.0895 ┆ … ┆ Ruby   ┆ 2024-09-02 ┆ 22:10:00 ┆ 2024-09-02 22:10:00 │
# │ 3   ┆ 6.6    ┆ 9.999  ┆ 0.7946  ┆ … ┆ Rust   ┆ 2024-09-03 ┆ 23:20:00 ┆ 2024-09-03 23:20:00 │
# └─────┴────────┴────────┴─────────┴───┴────────┴────────────┴──────────┴─────────────────────┘, _body=<great_tables._gt_data.Body object at 0x000001D57721A810>, _boxhead=Boxhead([ColInfo(var='int', type=<ColInfoTypeEnum.default: 1>, column_label='int', column_align='right', column_width=None), ColInfo(var='float1', type=<ColInfoTypeEnum.default: 1>, column_label='float1', column_align='right', column_width=None), ColInfo(var='float2', type=<ColInfoTypeEnum.default: 1>, column_label='float2', column_align='right', column_width=None), ColInfo(var='perc', type=<ColInfoTypeEnum.default: 1>, column_label='perc', column_align='right', column_width=None), ColInfo(var='sci', type=<ColInfoTypeEnum.default: 1>, column_label='sci', column_align='right', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None), ColInfo(var='str', type=<ColInfoTypeEnum.default: 1>, column_label='str', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='center', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001D5068BA090>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001D5068BA9D0>, _formats=[<great_tables._gt_data.FormatInfo object at 0x000001D5068BBE50>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table ...

# %% [markdown]
# ## fmt_percent

# %%
(GT(df_demo).fmt_percent("perc"))
# Out:
# GT(_tbl_data=shape: (3, 10)
# ┌─────┬────────┬────────┬─────────┬───┬────────┬────────────┬──────────┬─────────────────────┐
# │ int ┆ float1 ┆ float2 ┆ perc    ┆ … ┆ str    ┆ date       ┆ time     ┆ datetime            │
# │ --- ┆ ---    ┆ ---    ┆ ---     ┆   ┆ ---    ┆ ---        ┆ ---      ┆ ---                 │
# │ i64 ┆ f64    ┆ f64    ┆ f64     ┆   ┆ str    ┆ date       ┆ time     ┆ datetime[μs]        │
# ╞═════╪════════╪════════╪═════════╪═══╪════════╪════════════╪══════════╪═════════════════════╡
# │ 1   ┆ 4.4    ┆ 7.7    ┆ 0.5401  ┆ … ┆ Python ┆ 2024-09-01 ┆ 21:00:00 ┆ 2024-09-01 21:00:00 │
# │ 2   ┆ 5.5    ┆ 8.88   ┆ -0.0895 ┆ … ┆ Ruby   ┆ 2024-09-02 ┆ 22:10:00 ┆ 2024-09-02 22:10:00 │
# │ 3   ┆ 6.6    ┆ 9.999  ┆ 0.7946  ┆ … ┆ Rust   ┆ 2024-09-03 ┆ 23:20:00 ┆ 2024-09-03 23:20:00 │
# └─────┴────────┴────────┴─────────┴───┴────────┴────────────┴──────────┴─────────────────────┘, _body=<great_tables._gt_data.Body object at 0x000001D5068BB210>, _boxhead=Boxhead([ColInfo(var='int', type=<ColInfoTypeEnum.default: 1>, column_label='int', column_align='right', column_width=None), ColInfo(var='float1', type=<ColInfoTypeEnum.default: 1>, column_label='float1', column_align='right', column_width=None), ColInfo(var='float2', type=<ColInfoTypeEnum.default: 1>, column_label='float2', column_align='right', column_width=None), ColInfo(var='perc', type=<ColInfoTypeEnum.default: 1>, column_label='perc', column_align='right', column_width=None), ColInfo(var='sci', type=<ColInfoTypeEnum.default: 1>, column_label='sci', column_align='right', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None), ColInfo(var='str', type=<ColInfoTypeEnum.default: 1>, column_label='str', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='center', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001D5068B21D0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001D5068B0850>, _formats=[<great_tables._gt_data.FormatInfo object at 0x000001D5068B3690>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table ...

# %%
(GT(df_demo).fmt_percent("perc", decimals=1))
# Out:
# GT(_tbl_data=shape: (3, 10)
# ┌─────┬────────┬────────┬─────────┬───┬────────┬────────────┬──────────┬─────────────────────┐
# │ int ┆ float1 ┆ float2 ┆ perc    ┆ … ┆ str    ┆ date       ┆ time     ┆ datetime            │
# │ --- ┆ ---    ┆ ---    ┆ ---     ┆   ┆ ---    ┆ ---        ┆ ---      ┆ ---                 │
# │ i64 ┆ f64    ┆ f64    ┆ f64     ┆   ┆ str    ┆ date       ┆ time     ┆ datetime[μs]        │
# ╞═════╪════════╪════════╪═════════╪═══╪════════╪════════════╪══════════╪═════════════════════╡
# │ 1   ┆ 4.4    ┆ 7.7    ┆ 0.5401  ┆ … ┆ Python ┆ 2024-09-01 ┆ 21:00:00 ┆ 2024-09-01 21:00:00 │
# │ 2   ┆ 5.5    ┆ 8.88   ┆ -0.0895 ┆ … ┆ Ruby   ┆ 2024-09-02 ┆ 22:10:00 ┆ 2024-09-02 22:10:00 │
# │ 3   ┆ 6.6    ┆ 9.999  ┆ 0.7946  ┆ … ┆ Rust   ┆ 2024-09-03 ┆ 23:20:00 ┆ 2024-09-03 23:20:00 │
# └─────┴────────┴────────┴─────────┴───┴────────┴────────────┴──────────┴─────────────────────┘, _body=<great_tables._gt_data.Body object at 0x000001D5068A0C10>, _boxhead=Boxhead([ColInfo(var='int', type=<ColInfoTypeEnum.default: 1>, column_label='int', column_align='right', column_width=None), ColInfo(var='float1', type=<ColInfoTypeEnum.default: 1>, column_label='float1', column_align='right', column_width=None), ColInfo(var='float2', type=<ColInfoTypeEnum.default: 1>, column_label='float2', column_align='right', column_width=None), ColInfo(var='perc', type=<ColInfoTypeEnum.default: 1>, column_label='perc', column_align='right', column_width=None), ColInfo(var='sci', type=<ColInfoTypeEnum.default: 1>, column_label='sci', column_align='right', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None), ColInfo(var='str', type=<ColInfoTypeEnum.default: 1>, column_label='str', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='center', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001D5068B1150>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001D5068B3050>, _formats=[<great_tables._gt_data.FormatInfo object at 0x000001D5068B2E90>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table ...

# %%
(GT(df_demo).fmt_percent("perc", decimals=1, incl_space=True))
# Out:
# GT(_tbl_data=shape: (3, 10)
# ┌─────┬────────┬────────┬─────────┬───┬────────┬────────────┬──────────┬─────────────────────┐
# │ int ┆ float1 ┆ float2 ┆ perc    ┆ … ┆ str    ┆ date       ┆ time     ┆ datetime            │
# │ --- ┆ ---    ┆ ---    ┆ ---     ┆   ┆ ---    ┆ ---        ┆ ---      ┆ ---                 │
# │ i64 ┆ f64    ┆ f64    ┆ f64     ┆   ┆ str    ┆ date       ┆ time     ┆ datetime[μs]        │
# ╞═════╪════════╪════════╪═════════╪═══╪════════╪════════════╪══════════╪═════════════════════╡
# │ 1   ┆ 4.4    ┆ 7.7    ┆ 0.5401  ┆ … ┆ Python ┆ 2024-09-01 ┆ 21:00:00 ┆ 2024-09-01 21:00:00 │
# │ 2   ┆ 5.5    ┆ 8.88   ┆ -0.0895 ┆ … ┆ Ruby   ┆ 2024-09-02 ┆ 22:10:00 ┆ 2024-09-02 22:10:00 │
# │ 3   ┆ 6.6    ┆ 9.999  ┆ 0.7946  ┆ … ┆ Rust   ┆ 2024-09-03 ┆ 23:20:00 ┆ 2024-09-03 23:20:00 │
# └─────┴────────┴────────┴─────────┴───┴────────┴────────────┴──────────┴─────────────────────┘, _body=<great_tables._gt_data.Body object at 0x000001D5068C06D0>, _boxhead=Boxhead([ColInfo(var='int', type=<ColInfoTypeEnum.default: 1>, column_label='int', column_align='right', column_width=None), ColInfo(var='float1', type=<ColInfoTypeEnum.default: 1>, column_label='float1', column_align='right', column_width=None), ColInfo(var='float2', type=<ColInfoTypeEnum.default: 1>, column_label='float2', column_align='right', column_width=None), ColInfo(var='perc', type=<ColInfoTypeEnum.default: 1>, column_label='perc', column_align='right', column_width=None), ColInfo(var='sci', type=<ColInfoTypeEnum.default: 1>, column_label='sci', column_align='right', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None), ColInfo(var='str', type=<ColInfoTypeEnum.default: 1>, column_label='str', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='center', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001D5068C1FD0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001D5068C1050>, _formats=[<great_tables._gt_data.FormatInfo object at 0x000001D5068C3750>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table ...

# %% [markdown]
# ## fmt_currency

# %%
(GT(df_demo).fmt_currency("sci"))
# Out:
# GT(_tbl_data=shape: (3, 10)
# ┌─────┬────────┬────────┬─────────┬───┬────────┬────────────┬──────────┬─────────────────────┐
# │ int ┆ float1 ┆ float2 ┆ perc    ┆ … ┆ str    ┆ date       ┆ time     ┆ datetime            │
# │ --- ┆ ---    ┆ ---    ┆ ---     ┆   ┆ ---    ┆ ---        ┆ ---      ┆ ---                 │
# │ i64 ┆ f64    ┆ f64    ┆ f64     ┆   ┆ str    ┆ date       ┆ time     ┆ datetime[μs]        │
# ╞═════╪════════╪════════╪═════════╪═══╪════════╪════════════╪══════════╪═════════════════════╡
# │ 1   ┆ 4.4    ┆ 7.7    ┆ 0.5401  ┆ … ┆ Python ┆ 2024-09-01 ┆ 21:00:00 ┆ 2024-09-01 21:00:00 │
# │ 2   ┆ 5.5    ┆ 8.88   ┆ -0.0895 ┆ … ┆ Ruby   ┆ 2024-09-02 ┆ 22:10:00 ┆ 2024-09-02 22:10:00 │
# │ 3   ┆ 6.6    ┆ 9.999  ┆ 0.7946  ┆ … ┆ Rust   ┆ 2024-09-03 ┆ 23:20:00 ┆ 2024-09-03 23:20:00 │
# └─────┴────────┴────────┴─────────┴───┴────────┴────────────┴──────────┴─────────────────────┘, _body=<great_tables._gt_data.Body object at 0x000001D5068A30D0>, _boxhead=Boxhead([ColInfo(var='int', type=<ColInfoTypeEnum.default: 1>, column_label='int', column_align='right', column_width=None), ColInfo(var='float1', type=<ColInfoTypeEnum.default: 1>, column_label='float1', column_align='right', column_width=None), ColInfo(var='float2', type=<ColInfoTypeEnum.default: 1>, column_label='float2', column_align='right', column_width=None), ColInfo(var='perc', type=<ColInfoTypeEnum.default: 1>, column_label='perc', column_align='right', column_width=None), ColInfo(var='sci', type=<ColInfoTypeEnum.default: 1>, column_label='sci', column_align='right', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None), ColInfo(var='str', type=<ColInfoTypeEnum.default: 1>, column_label='str', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='center', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001D5068B2610>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001D5068C0FD0>, _formats=[<great_tables._gt_data.FormatInfo object at 0x000001D5068C3190>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table ...

# %%
(GT(df_demo).fmt_currency("sci", decimals=0, currency="JPY", scale_by=4.4))
# Out:
# GT(_tbl_data=shape: (3, 10)
# ┌─────┬────────┬────────┬─────────┬───┬────────┬────────────┬──────────┬─────────────────────┐
# │ int ┆ float1 ┆ float2 ┆ perc    ┆ … ┆ str    ┆ date       ┆ time     ┆ datetime            │
# │ --- ┆ ---    ┆ ---    ┆ ---     ┆   ┆ ---    ┆ ---        ┆ ---      ┆ ---                 │
# │ i64 ┆ f64    ┆ f64    ┆ f64     ┆   ┆ str    ┆ date       ┆ time     ┆ datetime[μs]        │
# ╞═════╪════════╪════════╪═════════╪═══╪════════╪════════════╪══════════╪═════════════════════╡
# │ 1   ┆ 4.4    ┆ 7.7    ┆ 0.5401  ┆ … ┆ Python ┆ 2024-09-01 ┆ 21:00:00 ┆ 2024-09-01 21:00:00 │
# │ 2   ┆ 5.5    ┆ 8.88   ┆ -0.0895 ┆ … ┆ Ruby   ┆ 2024-09-02 ┆ 22:10:00 ┆ 2024-09-02 22:10:00 │
# │ 3   ┆ 6.6    ┆ 9.999  ┆ 0.7946  ┆ … ┆ Rust   ┆ 2024-09-03 ┆ 23:20:00 ┆ 2024-09-03 23:20:00 │
# └─────┴────────┴────────┴─────────┴───┴────────┴────────────┴──────────┴─────────────────────┘, _body=<great_tables._gt_data.Body object at 0x000001D5068BB0D0>, _boxhead=Boxhead([ColInfo(var='int', type=<ColInfoTypeEnum.default: 1>, column_label='int', column_align='right', column_width=None), ColInfo(var='float1', type=<ColInfoTypeEnum.default: 1>, column_label='float1', column_align='right', column_width=None), ColInfo(var='float2', type=<ColInfoTypeEnum.default: 1>, column_label='float2', column_align='right', column_width=None), ColInfo(var='perc', type=<ColInfoTypeEnum.default: 1>, column_label='perc', column_align='right', column_width=None), ColInfo(var='sci', type=<ColInfoTypeEnum.default: 1>, column_label='sci', column_align='right', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None), ColInfo(var='str', type=<ColInfoTypeEnum.default: 1>, column_label='str', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='center', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001D5068D42D0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001D5068D5AD0>, _formats=[<great_tables._gt_data.FormatInfo object at 0x000001D5068C0850>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table ...

# %%
(GT(df_demo).fmt_currency("sci", locale="ja"))
# Out:
# GT(_tbl_data=shape: (3, 10)
# ┌─────┬────────┬────────┬─────────┬───┬────────┬────────────┬──────────┬─────────────────────┐
# │ int ┆ float1 ┆ float2 ┆ perc    ┆ … ┆ str    ┆ date       ┆ time     ┆ datetime            │
# │ --- ┆ ---    ┆ ---    ┆ ---     ┆   ┆ ---    ┆ ---        ┆ ---      ┆ ---                 │
# │ i64 ┆ f64    ┆ f64    ┆ f64     ┆   ┆ str    ┆ date       ┆ time     ┆ datetime[μs]        │
# ╞═════╪════════╪════════╪═════════╪═══╪════════╪════════════╪══════════╪═════════════════════╡
# │ 1   ┆ 4.4    ┆ 7.7    ┆ 0.5401  ┆ … ┆ Python ┆ 2024-09-01 ┆ 21:00:00 ┆ 2024-09-01 21:00:00 │
# │ 2   ┆ 5.5    ┆ 8.88   ┆ -0.0895 ┆ … ┆ Ruby   ┆ 2024-09-02 ┆ 22:10:00 ┆ 2024-09-02 22:10:00 │
# │ 3   ┆ 6.6    ┆ 9.999  ┆ 0.7946  ┆ … ┆ Rust   ┆ 2024-09-03 ┆ 23:20:00 ┆ 2024-09-03 23:20:00 │
# └─────┴────────┴────────┴─────────┴───┴────────┴────────────┴──────────┴─────────────────────┘, _body=<great_tables._gt_data.Body object at 0x000001D5068A2A50>, _boxhead=Boxhead([ColInfo(var='int', type=<ColInfoTypeEnum.default: 1>, column_label='int', column_align='right', column_width=None), ColInfo(var='float1', type=<ColInfoTypeEnum.default: 1>, column_label='float1', column_align='right', column_width=None), ColInfo(var='float2', type=<ColInfoTypeEnum.default: 1>, column_label='float2', column_align='right', column_width=None), ColInfo(var='perc', type=<ColInfoTypeEnum.default: 1>, column_label='perc', column_align='right', column_width=None), ColInfo(var='sci', type=<ColInfoTypeEnum.default: 1>, column_label='sci', column_align='right', column_width=None), ColInfo(var='group', type=<ColInfoTypeEnum.default: 1>, column_label='group', column_align='left', column_width=None), ColInfo(var='str', type=<ColInfoTypeEnum.default: 1>, column_label='str', column_align='left', column_width=None), ColInfo(var='date', type=<ColInfoTypeEnum.default: 1>, column_label='date', column_align='right', column_width=None), ColInfo(var='time', type=<ColInfoTypeEnum.default: 1>, column_label='time', column_align='center', column_width=None), ColInfo(var='datetime', type=<ColInfoTypeEnum.default: 1>, column_label='datetime', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001D50688BB90>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001D5068AB490>, _formats=[<great_tables._gt_data.FormatInfo object at 0x000001D50689D5D0>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table ...
